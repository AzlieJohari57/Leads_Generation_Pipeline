# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import glob
import requests
import time

# %%
parquet_path = "./Staging/Gold/cleaned_second_592.parquet"
if os.path.exists(parquet_path):
    RecordOwl_Leads = pd.read_parquet(parquet_path, engine="fastparquet")
    print(f"Loaded {len(RecordOwl_Leads)} rows from {parquet_path}")
    print(RecordOwl_Leads.shape)
else:
    raise FileNotFoundError(f"Parquet file not found at {parquet_path}")

filtered_df = RecordOwl_Leads[
    RecordOwl_Leads["PIC NAME 1 Contact Number"].notna() &
    (RecordOwl_Leads["PIC NAME 1 Contact Number"] != "")
]

filtered_df
# Out:
# Loaded 592 rows from ./Staging/Gold/cleaned_second_592.parquet
# (592, 62)
#     ePOS Code Company Code       Date  \
# 0        None         None 2025-11-18
# 1        None         None 2025-11-18
# 2        None         None 2025-11-18
# 3        None         None 2025-11-18
# 4        None         None 2025-11-18
# ..        ...          ...        ...
# 272      None         None 2025-11-18
# 273      None         None 2025-11-18
# 274      None         None 2025-11-18
# 275      None         None 2025-11-18
# 276      None         None 2025-11-18
#
#                             ACRA REGISTERED NAME  \
# 0                        K-JOY EDUCARE PTE. LTD.
# 1                                 TUNGSTAN EDLAB
# 2    ADVENTURE TREE PRESCHOOL BRADDELL PTE. LTD.
# 3    GLOBAL ACHIEVERS EDUCATION CENTRE PTE. LTD.
# 4                SG NOAH'S ARK EDUTECH PTE. LTD.
# ..                                           ...
# 272                  CEREBRO EDUCATION PTE. LTD.
# 273                AMARKIDZ@MACPHERSON PTE. LTD.
# 274                        ST EDUCATION SERVICES
# 275        MPGL CHILDCARE CENTRE (KHC) PTE. LTD.
# 276                   WE CARE EDUCATION SERVICES
#
#          Brand/Deal Name/Business Name  \
# 0                        K-JOY EDUCARE
# 1                       TUNGSTAN EDLAB
# 2    ADVENTURE TREE PRESCHOOL BRADDELL
# 3           ACHIEVERS EDUCATION CENTRE
# 4                    NOAHS ARK EDUTECH
# ..                                 ...
# 272                  CEREBRO EDUCATION
# 273                AMARKIDZ@MACPHERSON
# 274                       ST EDUCATION
# 275          MPGL CHILDCARE CENTRE KHC
# 276                  WE CARE EDUCATION
#
#     Sub Domain Link (If Lead is already available in Backend) Fill only when EPOS client  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 272                                               None
# 273                                               None
# 274                                               None
# 275                                               None
# 276                                               None
#
#     Tele Sales or MR (For KPI - Internal) Name of the Market Researcher  \
# 0                               TeleSales                      Shafiqah
# 1                               TeleSales                      Shafiqah
# 2                               TeleSales                      Shafiqah
# 3                               TeleSales                      Shafiqah
# 4                               TeleSales                      Shafiqah
# ..                                    ...                           ...
# 272                             TeleSales                      Shafiqah
# 273                             TeleSales                      Shafiqah
# 274                             TeleSales                      Shafiqah
# 275                             TeleSales                      Shafiqah
# 276                             TeleSales                      Shafiqah
#
#     Original Source (Marketing)  \
# 0               Offline Sources
# 1               Offline Sources
# 2               Offline Sources
# 3               Offline Sources
# 4               Offline Sources
# ..                          ...
# 272             Offline Sources
# 273             Offline Sources
# 274             Offline Sources
# 275             Offline Sources
# 276             Offline Sources
#
#     Marketing Source (Do not fill anything if the leads are from Hubspot, EPOS clients)  \
# 0                                        Web Scrapping
# 1                                        Web Scrapping
# 2                                        Web Scrapping
# 3                                        Web Scrapping
# 4                                        Web Scrapping
# ..                                                 ...
# 272                                      Web Scrapping
# 273                                      Web Scrapping
# 274                                      Web Scrapping
# 275                                      Web Scrapping
# 276                                      Web Scrapping
#
#      ... PIC Name Designation 3 PIC NAME 3 Contact Number  \
# 0    ...                   None                      None
# 1    ...                   None                      None
# 2    ...                   None                      None
# 3    ...                   None                      None
# 4    ...                   None                      None
# ..   ...                    ...                       ...
# 272  ...                   None                      None
# 273  ...                   None                      None
# 274  ...                   None                      None
# 275  ...                   None                      None
# 276  ...                   None                      None
#
#      PIC 3 email address  FB/Insta/Tik Tok/Linkedin Contact  \
# 0                   None                               None
# 1                   None                               None
# 2                   None                               None
# 3                   None                               None
# 4                   None                               None
# ..                   ...                                ...
# 272                 None                               None
# 273                 None                               None
# 274                 None                               None
# 275                 None                               None
# 276                 None                               None
#
#     Current ePOS Client ? If ePOS Client, which product they are using?  \
# 0                    None                                          None
# 1                    None                                          None
# 2                    None                                          None
# 3                    None                                          None
# 4                    None                                          None
# ..                    ...                                           ...
# 272                  None                                          None
# 273                  None                                          None
# 274                  None                                          None
# 275                  None                                          None
# 276                  None                                          None
#
#     Is this deal part of the Gov List? Source from Market Researcher  \
# 0                             Gov List         ACRA, Google Searches
# 1                             Gov List         ACRA, Google Searches
# 2                             Gov List         ACRA, Google Searches
# 3                             Gov List         ACRA, Google Searches
# 4                             Gov List         ACRA, Google Searches
# ..                                 ...                           ...
# 272                           Gov List         ACRA, Google Searches
# 273                           Gov List         ACRA, Google Searches
# 274                           Gov List         ACRA, Google Searches
# 275                           Gov List         ACRA, Google Searches
# 276                           Gov List         ACRA, Google Searches
#
#     Contact Number from Lusha? Phone number Verified ?
# 0                         None                    None
# 1                         None                    None
# 2                         None                    None
# 3                         None                    None
# 4                         None                    None
# ..                         ...                     ...
# 272                       None                    None
# 273                       None                    None
# 274                       None                    None
# 275                       None                    None
# 276                       None                    None
#
# [277 rows x 62 columns]

# %%
companies_df = filtered_df.head(50).copy()
companies_df.shape
# Out:
# (50, 62)

# %% [markdown]
# ### Lusha Scrapping

# %%
# API Configuration
API_KEY = "15304a36-d527-4f30-b250-b79cd409a464"
BASE_URL = "https://api.lusha.com"
CONTACT_SEARCH_ENDPOINT = f"{BASE_URL}/prospecting/contact/search"
CONTACT_ENRICH_ENDPOINT = f"{BASE_URL}/prospecting/contact/enrich"

headers = {
    "api_key": API_KEY,
    "Content-Type": "application/json"
}

# Key decision maker titles (prioritized)
DECISION_MAKER_KEYWORDS = [
    'ceo', 'chief executive', 'founder', 'co-founder', 'owner', 'president',
    'director', 'managing director', 'general manager', 'head', 'principal',
    'chairman', 'chairwoman', 'partner', 'proprietor'
]

def is_decision_maker(title):
    """Check if title indicates a key decision maker"""
    if not title or title == 'N/A':
        return False
    title_lower = title.lower()
    return any(keyword in title_lower for keyword in DECISION_MAKER_KEYWORDS)

def extract_singapore_mobile(phone_numbers):
    """
    Extract Singapore mobile number from phone numbers list.
    Singapore mobile numbers: +65 8XXX XXXX or +65 9XXX XXXX
    Returns the first mobile number found, or None if no mobile found
    """
    if not phone_numbers or len(phone_numbers) == 0:
        return None
    
    for phone_obj in phone_numbers:
        number = phone_obj.get('number', '')
        phone_type = phone_obj.get('type', '').lower()
        
        # Clean the number for checking
        clean_number = number.replace(' ', '').replace('-', '')
        
        # Check if it's a Singapore number
        if clean_number.startswith('+65'):
            # Check if it's a mobile (starts with 8 or 9)
            if len(clean_number) >= 4:
                mobile_prefix = clean_number[3]  # Character after +65
                if mobile_prefix in ['8', '9']:
                    return number
        
        # Also check by type if available
        if phone_type in ['mobile', 'mobile_phone', 'personal']:
            if clean_number.startswith('+65'):
                return number
    
    return None

def enrich_contacts_batch(request_id, contact_ids):
    """Enrich multiple contacts and return full phone data"""
    if not contact_ids:
        return {}
    
    enrich_payload = {
        "requestId": request_id,
        "contactIds": contact_ids
    }
    
    try:
        response = requests.post(CONTACT_ENRICH_ENDPOINT, headers=headers, json=enrich_payload)
        
        if response.status_code in [200, 201]:
            data = response.json()
            
            contact_map = {}
            if data.get('contacts') and isinstance(data['contacts'], list):
                for contact in data['contacts']:
                    contact_id = contact.get('id') or contact.get('contactId')
                    phones = contact.get('data', {}).get('phoneNumbers', [])
                    contact_map[contact_id] = phones
            
            return contact_map
        else:
            print(f"  [ERROR] Enrich Error {response.status_code}")
            return {}
    
    except Exception as e:
        print(f"  [ERROR] Enrich Exception: {str(e)}")
        return {}

def search_all_companies_optimized(company_names, batch_size=50):
    """Search all companies in batches to minimize credits (max 50 per Lusha API limit)
    Filters for Singapore-based contacts to increase likelihood of +65 numbers"""
    all_contacts_by_company = {}
    total_credits = 0
    
    for batch_start in range(0, len(company_names), batch_size):
        batch = company_names[batch_start:batch_start + batch_size]
        
        print(f"\n{'='*80}")
        print(f"BATCH {batch_start//batch_size + 1}: Searching {len(batch)} companies in ONE request")
        print(f"{'='*80}")
        
        payload = {
            "pages": {"page": 0, "size": len(batch)},  # Use actual batch length, not batch_size
            "filters": {
                "contacts": {
                    "include": {
                        "existing_data_points": ["phone", "mobile_phone"],
                        "locations": [{"country": "SG"}]  # Filter for Singapore-based contacts
                    }
                },
                "companies": {
                    "include": {"names": batch}
                }
            }
        }
        
        try:
            response = requests.post(CONTACT_SEARCH_ENDPOINT, headers=headers, json=payload)
            
            if response.status_code in [200, 201]:
                data = response.json()
                contacts = data.get('data', [])
                request_id = data.get('requestId', '')
                credits = data.get('billing', {}).get('creditsCharged', 0)
                total_credits += credits
                
                print(f"[OK] Found {len(contacts)} SG-based contacts across {len(batch)} companies")
                print(f"[OK] Credits charged: {credits} (vs {len(batch)} if searched individually)")
                print(f"[OK] Savings: {len(batch) - credits} credits!")
                
                # Group contacts by company
                for contact in contacts:
                    company = contact.get('companyName', '')
                    if company not in all_contacts_by_company:
                        all_contacts_by_company[company] = []
                    all_contacts_by_company[company].append({
                        'contact': contact,
                        'request_id': request_id
                    })
                
                time.sleep(0.1)
            else:
                print(f"[ERROR] Search Error {response.status_code}: {response.text[:200]}")
        
        except Exception as e:
            print(f"[ERROR] Exception: {str(e)}")
    
    print(f"\n{'='*80}")
    print(f"[CREDITS] Total search credits used: {total_credits} (vs {len(company_names)} individual searches)")
    print(f"[SAVINGS] Credit savings: {len(company_names) - total_credits}")
    print(f"{'='*80}\n")
    
    return all_contacts_by_company, total_credits

def get_company_contacts_sg_optimized(companies_df):
    """
    SUPER OPTIMIZED: Get best Singapore contact for each company
    - FILTERS for Singapore-based contacts in search (higher +65 probability!)
    - PRE-FILTERS using hasMobilePhone flag BEFORE enriching (HUGE savings!)
    - Filters for Singapore mobile numbers (+65 8XXX/9XXX) 
    - Prioritizes key decision makers
    - Minimal credit usage
    """
    company_names = companies_df['ACRA REGISTERED NAME'].tolist()
    
    # Step 1: Search all companies in batches (max 50 per Lusha API limit)
    # Now filtering for Singapore-based contacts!
    contacts_by_company, search_credits = search_all_companies_optimized(company_names, batch_size=50)
    
    # Step 2: Smart filtering and enrichment - ONLY enrich contacts with mobile flags!
    results = []
    enrich_credits = 0
    skipped_no_mobile_flag = 0
    
    print("\n" + "="*80)
    print("FINDING BEST SINGAPORE CONTACT PER COMPANY")
    print("="*80)
    
    for company_name in company_names:
        # Find matching company (case-insensitive partial match)
        matched_company = None
        for key in contacts_by_company.keys():
            if company_name.upper() in key.upper() or key.upper() in company_name.upper():
                matched_company = key
                break
        
        if matched_company and contacts_by_company[matched_company]:
            all_contacts = contacts_by_company[matched_company]
            
            print(f"\n{company_name}:")
            print(f"  Found {len(all_contacts)} contacts")
            
            # SMART PRE-FILTERING: Only enrich contacts with hasMobilePhone=True!
            # Priority 1: Decision makers with mobile phone flag
            decision_makers_with_mobile = [
                c for c in all_contacts 
                if is_decision_maker(c['contact'].get('jobTitle', ''))
                and c['contact'].get('hasMobilePhone', False) == True
            ]
            
            # Priority 2: Any decision maker (even without mobile flag)
            decision_makers_any = [
                c for c in all_contacts 
                if is_decision_maker(c['contact'].get('jobTitle', ''))
            ]
            
            # Priority 3: Anyone with mobile phone flag
            anyone_with_mobile = [
                c for c in all_contacts 
                if c['contact'].get('hasMobilePhone', False) == True
            ]
            
            # Priority 4: Last resort - anyone
            fallback_contacts = all_contacts
            
            # Select best tier available
            if decision_makers_with_mobile:
                contacts_to_check = decision_makers_with_mobile
                print(f"  Strategy: Decision makers with mobile flag ({len(contacts_to_check)} contacts)")
            elif anyone_with_mobile:
                contacts_to_check = anyone_with_mobile
                print(f"  Strategy: Anyone with mobile flag ({len(contacts_to_check)} contacts)")
            elif decision_makers_any:
                contacts_to_check = decision_makers_any
                print(f"  Strategy: Any decision maker ({len(contacts_to_check)} contacts)")
            else:
                contacts_to_check = fallback_contacts[:3]  # Limit fallback to 3
                print(f"  Strategy: Fallback - first 3 contacts")
            
            best_contact = None
            best_phone = None
            
            # Now enrich only the filtered contacts
            for contact_data in contacts_to_check:
                contact = contact_data['contact']
                request_id = contact_data['request_id']
                contact_id = contact.get('contactId')
                contact_name = contact.get('name', 'N/A')
                contact_title = contact.get('jobTitle', 'N/A')
                has_mobile_flag = contact.get('hasMobilePhone', False)
                
                print(f"  > Checking: {contact_name} ({contact_title}) [hasMobile: {has_mobile_flag}]")
                
                # Enrich to check for Singapore mobile
                if contact_id and request_id:
                    phone_map = enrich_contacts_batch(request_id, [contact_id])
                    phones = phone_map.get(contact_id, [])
                    
                    sg_mobile = extract_singapore_mobile(phones)
                    enrich_credits += 1
                    
                    if sg_mobile:
                        print(f"    [SG MOBILE FOUND] {sg_mobile}")
                        best_contact = contact
                        best_phone = sg_mobile
                        break  # Found what we need!
                    else:
                        print(f"    [SKIP] No SG mobile number")
                        if not has_mobile_flag:
                            skipped_no_mobile_flag += 1
                
                time.sleep(0.1)
            
            if best_contact and best_phone:
                results.append({
                    'Company': company_name,
                    'Contact_Name': best_contact.get('name', 'N/A'),
                    'Contact_Title': best_contact.get('jobTitle', 'N/A'),
                    'Contact_Number': best_phone,
                    'Is_Decision_Maker': 'Yes' if is_decision_maker(best_contact.get('jobTitle', '')) else 'No'
                })
            else:
                print(f"  [NONE] No Singapore mobile number found")
                results.append({
                    'Company': company_name,
                    'Contact_Name': 'N/A',
                    'Contact_Title': 'N/A',
                    'Contact_Number': 'N/A',
                    'Is_Decision_Maker': 'N/A'
                })
        else:
            print(f"\n{company_name}: No contacts found")
            results.append({
                'Company': company_name,
                'Contact_Name': 'N/A',
                'Contact_Title': 'N/A',
                'Contact_Number': 'N/A',
                'Is_Decision_Maker': 'N/A'
            })
    
    print(f"\n{'='*80}")
    print(f"[CREDITS] TOTAL CREDITS USED:")
    print(f"   Search: {search_credits} credits")
    print(f"   Enrich: {enrich_credits} credits")
    print(f"   Total: {search_credits + enrich_credits} credits")
    print(f"\n[SAVINGS] vs individual search: {len(company_names) - search_credits} credits!")
    print(f"[EFFICIENCY] Pre-filtered out {skipped_no_mobile_flag} enrichments by checking hasMobilePhone flag")
    print(f"{'='*80}\n")
    
    return pd.DataFrame(results)

# Run optimized version
print("="*80)
print("SUPER OPTIMIZED SG CONTACT SEARCH - SINGAPORE LOCATION FILTER")
print("="*80)

results_df = get_company_contacts_sg_optimized(companies_df)

print("\nFINAL RESULTS:")
print("="*80)
print(results_df.to_string(index=False))

# Add to dataframe
companies_df['Contact_Name'] = results_df['Contact_Name']
companies_df['Contact_Title'] = results_df['Contact_Title']
companies_df['Contact_Number'] = results_df['Contact_Number']
companies_df['Is_Decision_Maker'] = results_df['Is_Decision_Maker']
# Out:
# ================================================================================
# SUPER OPTIMIZED SG CONTACT SEARCH - SMART PRE-FILTERING
# ================================================================================
#
# ================================================================================
# BATCH 1: Searching 50 companies in ONE request
# ================================================================================
# [OK] Found 50 total contacts across 50 companies
# [OK] Credits charged: 2 (vs 50 if searched individually)
# [OK] Savings: 48 credits!
#
# ================================================================================
# [CREDITS] Total search credits used: 2 (vs 50 individual searches)
# [SAVINGS] Credit savings: 48
# ================================================================================
#
#
# ================================================================================
# FINDING BEST SINGAPORE CONTACT PER COMPANY
# ================================================================================
#
# K-JOY EDUCARE PTE. LTD.: No contacts found
#
# TUNGSTAN EDLAB: No contacts found
#
# ADVENTURE TREE PRESCHOOL BRADDELL PTE. LTD.: No contacts found
#
# GLOBAL ACHIEVERS EDUCATION CENTRE PTE. LTD.: No contacts found
#
# SG NOAH'S ARK EDUTECH PTE. LTD.: No contacts found
#
# ELITE EDUCATION & TALENT CENTRE PTE. LTD.: No contacts found
#
# THE LITTLE CHAMPIONS (TLC) PTE. LTD.: No contacts found
#
# BRAIN MATTER LLP: No contacts found
#
# MAPLEBEAR KIDS ADVENTURE PTE. LTD.: No contacts found
#
# TNTTUTORS TUITION AGENCY: No contacts found
#
# NEW VISION EDUCATION AND TECHNOLOGY PTE. LTD.: No contacts found
#
# BLOSSOM GENESIS CENTRE PTE. LTD.: No contacts found
#
# STARRY EDUCARE PTE. LTD.: No contacts found
#
# LANGUAGE LOFT PTE. LTD.: No contacts found
#
# CARPE DIEM STARLETS 2 PTE. LTD.: No contacts found
#
# SUPERLAND PRE-SCHOOL (BT) PTE. LTD.: No contacts found
#
# ILEAP LEARNING CENTRE LIMITED LIABILITY PARTNERSHIP:
#   Found 3 contacts
#   Strategy: Decision makers with mobile flag (1 contacts)
#   > Checking: Vignesh Hebbar (Founder, Chief Executive Officer) [hasMobile: True]
#     [SKIP] No SG mobile number
#   [NONE] No Singapore mobile number found
#
# THE UNIVERSE CLASSROOM (BRANCH) PTE. LTD.: No contacts found
#
# SWEETLANDS CHILDCARE WOODLANDS 896B PTE. LTD.: No contacts found
#
# HWAYANG EDUCATION PTE. LTD.: No contacts found
#
# ONWARDS EDUCATION CONSULTANCY PTE. LTD.: No contacts found
#
# SINGBLOOM PTE. LTD.: No contacts found
#
# DAYDAYUP LANGUAGE SCHOOL: No contacts found
#
# HUA CHENG EDUCATION CENTRE PTE LTD: No contacts found
#
# LYNN LEARNING HUB: No contacts found
#
# NORTHERN LANGUAGE SCHOOL PTE. LTD.: No contacts found
#
# RAFFLES HOUSE @ ADAM PTE. LTD.: No contacts found
#
# INSPIRE EDUCATION PTE. LTD.: No contacts found
#
# PRO WELLNESS COACH LLP: No contacts found
#
# KALLEIS TUITION: No contacts found
#
# THE ACADEMIC WORKSHOP PTE. LTD.: No contacts found
#
# YOULE MANDARIN EDUCATION CENTRE (PARKWAY) PTE. LTD.: No contacts found
#
# PRO-TEACH EDUCATION (YUHUA) LLP: No contacts found
#
# HERO EDUCATION PTE. LTD.: No contacts found
#
# LITTLE PROFESSORS LEARNING CENTRE (YI) PTE. LTD.: No contacts found
#
# SUNFLOWER PRESCHOOL @ WEST ROCK PTE. LTD.: No contacts found
#
# YE TONG EDUCATION PTE. LTD.: No contacts found
#
# ZEE JUNIORS: No contacts found
#
# TOP MARKS EDUCATION PTE. LTD.: No contacts found
#
# PACIFICA MUSIC ACADEMY LLP: No contacts found
#
# MIND STRETCHER LEARNING CENTRE (BUKIT PANJANG) PTE. LTD.: No contacts found
#
# YOUNG EDUCATION HUB: No contacts found
#
# LIGHTHOUSE EDUCARE PTE. LTD.: No contacts found
#
# SEEDS LEARNING PLACE @ TIDES PTE. LTD.: No contacts found
#
# IRIS COUNSELLING: No contacts found
#
# FUN WITH ABACUS SCHOOL PTE. LTD.: No contacts found
#
# MPM EDUCATION:
#   Found 1 contacts
#   Strategy: Decision makers with mobile flag (1 contacts)
#   > Checking: Michael Mezguini (Director) [hasMobile: True]
#     [SKIP] No SG mobile number
#   [NONE] No Singapore mobile number found
#
# LITTLE SMALL WONDER: No contacts found
#
# THE CONFERENCE BOARD (SINGAPORE) LTD.:
#   Found 40 contacts
#   Strategy: Decision makers with mobile flag (12 contacts)
#   > Checking: Laureen Knudsen (Program Director) [hasMobile: True]
#     [SKIP] No SG mobile number
#   > Checking: Gaurav Arora (Director) [hasMobile: True]
#     [SKIP] No SG mobile number
#   > Checking: Georgina Wilkins (Director) [hasMobile: True]
#     [SKIP] No SG mobile number
#   > Checking: Martin Wiese (Director of Corporate Responsibility and Sustainability) [hasMobile: True]
#     [SKIP] No SG mobile number
#   > Checking: Nicolas Sennegon (Commercial Director) [hasMobile: True]
#     [SKIP] No SG mobile number
#   > Checking: Amit Mohindra (Principal Research Fellow) [hasMobile: True]
#     [SKIP] No SG mobile number
#   > Checking: Lars Sudmann (Senior Fellow and Council Director for Strategy and Transformation and CFO Councils) [hasMobile: True]
#     [SKIP] No SG mobile number
#   > Checking: Natalie Fair (Conference Program Director) [hasMobile: True]
#     [SKIP] No SG mobile number
#   > Checking: Bob Armacost (Program Director of Information and Research Management) [hasMobile: True]
#     [SKIP] No SG mobile number
#   > Checking: Shawn O'Grady (Program Director) [hasMobile: True]
#     [SKIP] No SG mobile number
#   > Checking: Eugene Tan (Program Director of Supply Chain and Procurement) [hasMobile: True]
#     [SG MOBILE FOUND] +65 9822 5164
#
# LITTLE GEMS PRESCHOOL PTE. LTD.: No contacts found
#
# ================================================================================
# [CREDITS] TOTAL CREDITS USED:
#    Search: 2 credits
#    Enrich: 13 credits
#    Total: 15 credits
#
# [SAVINGS] vs individual search: 48 credits!
# [EFFICIENCY] Pre-filtered out 0 enrichments by checking hasMobilePhone flag
# ================================================================================
#
#
# FINAL RESULTS:
# ================================================================================
#                                                  Company Contact_Name                                    Contact_Title Contact_Number Is_Decision_Maker
#                                  K-JOY EDUCARE PTE. LTD.          N/A                                              N/A            N/A               N/A
#                                           TUNGSTAN EDLAB          N/A                                              N/A            N/A               N/A
#              ADVENTURE TREE PRESCHOOL BRADDELL PTE. LTD.          N/A                                              N/A            N/A               N/A
#              GLOBAL ACHIEVERS EDUCATION CENTRE PTE. LTD.          N/A                                              N/A            N/A               N/A
#                          SG NOAH'S ARK EDUTECH PTE. LTD.          N/A                                              N/A            N/A               N/A
#                ELITE EDUCATION & TALENT CENTRE PTE. LTD.          N/A                                              N/A            N/A               N/A
#                     THE LITTLE CHAMPIONS (TLC) PTE. LTD.          N/A                                              N/A            N/A               N/A
#                                         BRAIN MATTER LLP          N/A                                              N/A            N/A               N/A
#                       MAPLEBEAR KIDS ADVENTURE PTE. LTD.          N/A                                              N/A            N/A               N/A
#                                 TNTTUTORS TUITION AGENCY          N/A                                              N/A            N/A               N/A
#            NEW VISION EDUCATION AND TECHNOLOGY PTE. LTD.          N/A                                              N/A            N/A               N/A
#                         BLOSSOM GENESIS CENTRE PTE. LTD.          N/A                                              N/A            N/A               N/A
#                                 STARRY EDUCARE PTE. LTD.          N/A                                              N/A            N/A               N/A
#                                  LANGUAGE LOFT PTE. LTD.          N/A                                              N/A            N/A               N/A
#                          CARPE DIEM STARLETS 2 PTE. LTD.          N/A                                              N/A            N/A               N/A
#                      SUPERLAND PRE-SCHOOL (BT) PTE. LTD.          N/A                                              N/A            N/A               N/A
#      ILEAP LEARNING CENTRE LIMITED LIABILITY PARTNERSHIP          N/A                                              N/A            N/A               N/A
#                THE UNIVERSE CLASSROOM (BRANCH) PTE. LTD.          N/A                                              N/A            N/A               N/A
#            SWEETLANDS CHILDCARE WOODLANDS 896B PTE. LTD.          N/A                                              N/A            N/A               N/A
#                              HWAYANG EDUCATION PTE. LTD.          N/A                                              N/A            N/A               N/A
#                  ONWARDS EDUCATION CONSULTANCY PTE. LTD.          N/A                                              N/A            N/A               N/A
#                                      SINGBLOOM PTE. LTD.          N/A                                              N/A            N/A               N/A
#                                 DAYDAYUP LANGUAGE SCHOOL          N/A                                              N/A            N/A               N/A
#                       HUA CHENG EDUCATION CENTRE PTE LTD          N/A                                              N/A            N/A               N/A
#                                        LYNN LEARNING HUB          N/A                                              N/A            N/A               N/A
#                       NORTHERN LANGUAGE SCHOOL PTE. LTD.          N/A                                              N/A            N/A               N/A
#                           RAFFLES HOUSE @ ADAM PTE. LTD.          N/A                                              N/A            N/A               N/A
#                              INSPIRE EDUCATION PTE. LTD.          N/A                                              N/A            N/A               N/A
#                                   PRO WELLNESS COACH LLP          N/A                                              N/A            N/A               N/A
#                                          KALLEIS TUITION          N/A                                              N/A            N/A               N/A
#                          THE ACADEMIC WORKSHOP PTE. LTD.          N/A                                              N/A            N/A               N/A
#      YOULE MANDARIN EDUCATION CENTRE (PARKWAY) PTE. LTD.          N/A                                              N/A            N/A               N/A
#                          PRO-TEACH EDUCATION (YUHUA) LLP          N/A                                              N/A            N/A               N/A
#                                 HERO EDUCATION PTE. LTD.          N/A                                              N/A            N/A               N/A
#         LITTLE PROFESSORS LEARNING CENTRE (YI) PTE. LTD.          N/A                                              N/A            N/A               N/A
#                SUNFLOWER PRESCHOOL @ WEST ROCK PTE. LTD.          N/A                                              N/A            N/A               N/A
#                              YE TONG EDUCATION PTE. LTD.          N/A                                              N/A            N/A               N/A
#                                              ZEE JUNIORS          N/A                                              N/A            N/A               N/A
#                            TOP MARKS EDUCATION PTE. LTD.          N/A                                              N/A            N/A               N/A
#                               PACIFICA MUSIC ACADEMY LLP          N/A                                              N/A            N/A               N/A
# MIND STRETCHER LEARNING CENTRE (BUKIT PANJANG) PTE. LTD.          N/A                                              N/A            N/A               N/A
#                                      YOUNG EDUCATION HUB          N/A                                              N/A            N/A               N/A
#                             LIGHTHOUSE EDUCARE PTE. LTD.          N/A                                              N/A            N/A               N/A
#                   SEEDS LEARNING PLACE @ TIDES PTE. LTD.          N/A                                              N/A            N/A               N/A
#                                         IRIS COUNSELLING          N/A                                              N/A            N/A               N/A
#                         FUN WITH ABACUS SCHOOL PTE. LTD.          N/A                                              N/A            N/A               N/A
#                                            MPM EDUCATION          N/A                                              N/A            N/A               N/A
#                                      LITTLE SMALL WONDER          N/A                                              N/A            N/A               N/A
#                    THE CONFERENCE BOARD (SINGAPORE) LTD.   Eugene Tan Program Director of Supply Chain and Procurement  +65 9822 5164               Yes
#                          LITTLE GEMS PRESCHOOL PTE. LTD.          N/A                                              N/A            N/A               N/A

# %%
companies_df
# Out:
#    ePOS Code Company Code       Date  \
# 0       None         None 2025-11-18
# 1       None         None 2025-11-18
# 2       None         None 2025-11-18
# 3       None         None 2025-11-18
# 4       None         None 2025-11-18
# 5       None         None 2025-11-18
# 6       None         None 2025-11-18
# 7       None         None 2025-11-18
# 8       None         None 2025-11-18
# 9       None         None 2025-11-18
# 10      None         None 2025-11-18
# 11      None         None 2025-11-18
# 12      None         None 2025-11-18
# 13      None         None 2025-11-18
# 14      None         None 2025-11-18
# 15      None         None 2025-11-18
# 16      None         None 2025-11-18
# 17      None         None 2025-11-18
# 18      None         None 2025-11-18
# 19      None         None 2025-11-18
# 20      None         None 2025-11-18
# 21      None         None 2025-11-18
# 22      None         None 2025-11-18
# 23      None         None 2025-11-18
# 24      None         None 2025-11-18
# 25      None         None 2025-11-18
# 26      None         None 2025-11-18
# 27      None         None 2025-11-18
# 28      None         None 2025-11-18
# 29      None         None 2025-11-18
# 30      None         None 2025-11-18
# 31      None         None 2025-11-18
# 32      None         None 2025-11-18
# 33      None         None 2025-11-18
# 34      None         None 2025-11-18
# 35      None         None 2025-11-18
# 36      None         None 2025-11-18
# 37      None         None 2025-11-18
# 38      None         None 2025-11-18
# 39      None         None 2025-11-18
# 40      None         None 2025-11-18
# 41      None         None 2025-11-18
# 42      None         None 2025-11-18
# 43      None         None 2025-11-18
# 44      None         None 2025-11-18
# 45      None         None 2025-11-18
# 46      None         None 2025-11-18
# 47      None         None 2025-11-18
# 48      None         None 2025-11-18
# 49      None         None 2025-11-18
#
#                                  ACRA REGISTERED NAME  \
# 0                             K-JOY EDUCARE PTE. LTD.
# 1                                      TUNGSTAN EDLAB
# 2         ADVENTURE TREE PRESCHOOL BRADDELL PTE. LTD.
# 3         GLOBAL ACHIEVERS EDUCATION CENTRE PTE. LTD.
# 4                     SG NOAH'S ARK EDUTECH PTE. LTD.
# 5           ELITE EDUCATION & TALENT CENTRE PTE. LTD.
# 6                THE LITTLE CHAMPIONS (TLC) PTE. LTD.
# 7                                    BRAIN MATTER LLP
# 8                  MAPLEBEAR KIDS ADVENTURE PTE. LTD.
# 9                            TNTTUTORS TUITION AGENCY
# 10      NEW VISION EDUCATION AND TECHNOLOGY PTE. LTD.
# 11                   BLOSSOM GENESIS CENTRE PTE. LTD.
# 12                           STARRY EDUCARE PTE. LTD.
# 13                            LANGUAGE LOFT PTE. LTD.
# 14                    CARPE DIEM STARLETS 2 PTE. LTD.
# 15                SUPERLAND PRE-SCHOOL (BT) PTE. LTD.
# 16  ILEAP LEARNING CENTRE LIMITED LIABILITY PARTNE...
# 17          THE UNIVERSE CLASSROOM (BRANCH) PTE. LTD.
# 18      SWEETLANDS CHILDCARE WOODLANDS 896B PTE. LTD.
# 19                        HWAYANG EDUCATION PTE. LTD.
# 20            ONWARDS EDUCATION CONSULTANCY PTE. LTD.
# 21                                SINGBLOOM PTE. LTD.
# 22                           DAYDAYUP LANGUAGE SCHOOL
# 23                 HUA CHENG EDUCATION CENTRE PTE LTD
# 24                                  LYNN LEARNING HUB
# 25                 NORTHERN LANGUAGE SCHOOL PTE. LTD.
# 26                     RAFFLES HOUSE @ ADAM PTE. LTD.
# 27                        INSPIRE EDUCATION PTE. LTD.
# 28                             PRO WELLNESS COACH LLP
# 29                                    KALLEIS TUITION
# 30                    THE ACADEMIC WORKSHOP PTE. LTD.
# 31  YOULE MANDARIN EDUCATION CENTRE (PARKWAY) PTE....
# 32                    PRO-TEACH EDUCATION (YUHUA) LLP
# 33                           HERO EDUCATION PTE. LTD.
# 34   LITTLE PROFESSORS LEARNING CENTRE (YI) PTE. LTD.
# 35          SUNFLOWER PRESCHOOL @ WEST ROCK PTE. LTD.
# 36                        YE TONG EDUCATION PTE. LTD.
# 37                                        ZEE JUNIORS
# 38                      TOP MARKS EDUCATION PTE. LTD.
# 39                         PACIFICA MUSIC ACADEMY LLP
# 40  MIND STRETCHER LEARNING CENTRE (BUKIT PANJANG)...
# 41                                YOUNG EDUCATION HUB
# 42                       LIGHTHOUSE EDUCARE PTE. LTD.
# 43             SEEDS LEARNING PLACE @ TIDES PTE. LTD.
# 44                                   IRIS COUNSELLING
# 45                   FUN WITH ABACUS SCHOOL PTE. LTD.
# 46                                      MPM EDUCATION
# 47                                LITTLE SMALL WONDER
# 48              THE CONFERENCE BOARD (SINGAPORE) LTD.
# 49                    LITTLE GEMS PRESCHOOL PTE. LTD.
#
#                    Brand/Deal Name/Business Name  \
# 0                                  K-JOY EDUCARE
# 1                                 TUNGSTAN EDLAB
# 2              ADVENTURE TREE PRESCHOOL BRADDELL
# 3                     ACHIEVERS EDUCATION CENTRE
# 4                              NOAHS ARK EDUTECH
# 5                ELITE EDUCATION & TALENT CENTRE
# 6                       THE LITTLE CHAMPIONS TLC
# 7                                   BRAIN MATTER
# 8                       MAPLEBEAR KIDS ADVENTURE
# 9                       TNTTUTORS TUITION AGENCY
# 10           NEW VISION EDUCATION AND TECHNOLOGY
# 11                        BLOSSOM GENESIS CENTRE
# 12                                STARRY EDUCARE
# 13                                 LANGUAGE LOFT
# 14                         CARPE DIEM STARLETS 2
# 15                       SUPERLAND PRE-SCHOOL BT
# 16   ILEAP LEARNING CENTRE LIABILITY PARTNERSHIP
# 17                 THE UNIVERSE CLASSROOM BRANCH
# 18           SWEETLANDS CHILDCARE WOODLANDS 896B
# 19                             HWAYANG EDUCATION
# 20                 ONWARDS EDUCATION CONSULTANCY
# 21                                     SINGBLOOM
# 22                      DAYDAYUP LANGUAGE SCHOOL
# 23                    HUA CHENG EDUCATION CENTRE
# 24                             LYNN LEARNING HUB
# 25                      NORTHERN LANGUAGE SCHOOL
# 26                          RAFFLES HOUSE @ ADAM
# 27                             INSPIRE EDUCATION
# 28                            PRO WELLNESS COACH
# 29                               KALLEIS TUITION
# 30                         THE ACADEMIC WORKSHOP
# 31       YOULE MANDARIN EDUCATION CENTRE PARKWAY
# 32                     PRO-TEACH EDUCATION YUHUA
# 33                                HERO EDUCATION
# 34          LITTLE PROFESSORS LEARNING CENTRE YI
# 35               SUNFLOWER PRESCHOOL @ WEST ROCK
# 36                             YE TONG EDUCATION
# 37                                   ZEE JUNIORS
# 38                           TOP MARKS EDUCATION
# 39                        PACIFICA MUSIC ACADEMY
# 40  MIND STRETCHER LEARNING CENTRE BUKIT PANJANG
# 41                           YOUNG EDUCATION HUB
# 42                            LIGHTHOUSE EDUCARE
# 43                  SEEDS LEARNING PLACE @ TIDES
# 44                              IRIS COUNSELLING
# 45                        FUN WITH ABACUS SCHOOL
# 46                                 MPM EDUCATION
# 47                           LITTLE SMALL WONDER
# 48                          THE CONFERENCE BOARD
# 49                         LITTLE GEMS PRESCHOOL
#
#    Sub Domain Link (If Lead is already available in Backend) Fill only when EPOS client  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
#
#    Tele Sales or MR (For KPI - Internal) Name of the Market Researcher  \
# 0                              TeleSales                      Shafiqah
# 1                              TeleSales                      Shafiqah
# 2                              TeleSales                      Shafiqah
# 3                              TeleSales                      Shafiqah
# 4                              TeleSales                      Shafiqah
# 5                              TeleSales                      Shafiqah
# 6                              TeleSales                      Shafiqah
# 7                              TeleSales                      Shafiqah
# 8                              TeleSales                      Shafiqah
# 9                              TeleSales                      Shafiqah
# 10                             TeleSales                      Shafiqah
# 11                             TeleSales                      Shafiqah
# 12                             TeleSales                      Shafiqah
# 13                             TeleSales                      Shafiqah
# 14                             TeleSales                      Shafiqah
# 15                             TeleSales                      Shafiqah
# 16                             TeleSales                      Shafiqah
# 17                             TeleSales                      Shafiqah
# 18                             TeleSales                      Shafiqah
# 19                             TeleSales                      Shafiqah
# 20                             TeleSales                      Shafiqah
# 21                             TeleSales                      Shafiqah
# 22                             TeleSales                      Shafiqah
# 23                             TeleSales                      Shafiqah
# 24                             TeleSales                      Shafiqah
# 25                             TeleSales                      Shafiqah
# 26                             TeleSales                      Shafiqah
# 27                             TeleSales                      Shafiqah
# 28                             TeleSales                      Shafiqah
# 29                             TeleSales                      Shafiqah
# 30                             TeleSales                      Shafiqah
# 31                             TeleSales                      Shafiqah
# 32                             TeleSales                      Shafiqah
# 33                             TeleSales                      Shafiqah
# 34                             TeleSales                      Shafiqah
# 35                             TeleSales                      Shafiqah
# 36                             TeleSales                      Shafiqah
# 37                             TeleSales                      Shafiqah
# 38                             TeleSales                      Shafiqah
# 39                             TeleSales                      Shafiqah
# 40                             TeleSales                      Shafiqah
# 41                             TeleSales                      Shafiqah
# 42                             TeleSales                      Shafiqah
# 43                             TeleSales                      Shafiqah
# 44                             TeleSales                      Shafiqah
# 45                             TeleSales                      Shafiqah
# 46                             TeleSales                      Shafiqah
# 47                             TeleSales                      Shafiqah
# 48                             TeleSales                      Shafiqah
# 49                             TeleSales                      Shafiqah
#
#    Original Source (Marketing)  \
# 0              Offline Sources
# 1              Offline Sources
# 2              Offline Sources
# 3              Offline Sources
# 4              Offline Sources
# 5              Offline Sources
# 6              Offline Sources
# 7              Offline Sources
# 8              Offline Sources
# 9              Offline Sources
# 10             Offline Sources
# 11             Offline Sources
# 12             Offline Sources
# 13             Offline Sources
# 14             Offline Sources
# 15             Offline Sources
# 16             Offline Sources
# 17             Offline Sources
# 18             Offline Sources
# 19             Offline Sources
# 20             Offline Sources
# 21             Offline Sources
# 22             Offline Sources
# 23             Offline Sources
# 24             Offline Sources
# 25             Offline Sources
# 26             Offline Sources
# 27             Offline Sources
# 28             Offline Sources
# 29             Offline Sources
# 30             Offline Sources
# 31             Offline Sources
# 32             Offline Sources
# 33             Offline Sources
# 34             Offline Sources
# 35             Offline Sources
# 36             Offline Sources
# 37             Offline Sources
# 38             Offline Sources
# 39             Offline Sources
# 40             Offline Sources
# 41             Offline Sources
# 42             Offline Sources
# 43             Offline Sources
# 44             Offline Sources
# 45             Offline Sources
# 46             Offline Sources
# 47             Offline Sources
# 48             Offline Sources
# 49             Offline Sources
#
#    Marketing Source (Do not fill anything if the leads are from Hubspot, EPOS clients)  \
# 0                                       Web Scrapping
# 1                                       Web Scrapping
# 2                                       Web Scrapping
# 3                                       Web Scrapping
# 4                                       Web Scrapping
# 5                                       Web Scrapping
# 6                                       Web Scrapping
# 7                                       Web Scrapping
# 8                                       Web Scrapping
# 9                                       Web Scrapping
# 10                                      Web Scrapping
# 11                                      Web Scrapping
# 12                                      Web Scrapping
# 13                                      Web Scrapping
# 14                                      Web Scrapping
# 15                                      Web Scrapping
# 16                                      Web Scrapping
# 17                                      Web Scrapping
# 18                                      Web Scrapping
# 19                                      Web Scrapping
# 20                                      Web Scrapping
# 21                                      Web Scrapping
# 22                                      Web Scrapping
# 23                                      Web Scrapping
# 24                                      Web Scrapping
# 25                                      Web Scrapping
# 26                                      Web Scrapping
# 27                                      Web Scrapping
# 28                                      Web Scrapping
# 29                                      Web Scrapping
# 30                                      Web Scrapping
# 31                                      Web Scrapping
# 32                                      Web Scrapping
# 33                                      Web Scrapping
# 34                                      Web Scrapping
# 35                                      Web Scrapping
# 36                                      Web Scrapping
# 37                                      Web Scrapping
# 38                                      Web Scrapping
# 39                                      Web Scrapping
# 40                                      Web Scrapping
# 41                                      Web Scrapping
# 42                                      Web Scrapping
# 43                                      Web Scrapping
# 44                                      Web Scrapping
# 45                                      Web Scrapping
# 46                                      Web Scrapping
# 47                                      Web Scrapping
# 48                                      Web Scrapping
# 49                                      Web Scrapping
#
#     ... Current ePOS Client ? If ePOS Client, which product they are using?  \
# 0   ...                  None                                          None
# 1   ...                  None                                          None
# 2   ...                  None                                          None
# 3   ...                  None                                          None
# 4   ...                  None                                          None
# 5   ...                  None                                          None
# 6   ...                  None                                          None
# 7   ...                  None                                          None
# 8   ...                  None                                          None
# 9   ...                  None                                          None
# 10  ...                  None                                          None
# 11  ...                  None                                          None
# 12  ...                  None                                          None
# 13  ...                  None                                          None
# 14  ...                  None                                          None
# 15  ...                  None                                          None
# 16  ...                  None                                          None
# 17  ...                  None                                          None
# 18  ...                  None                                          None
# 19  ...                  None                                          None
# 20  ...                  None                                          None
# 21  ...                  None                                          None
# 22  ...                  None                                          None
# 23  ...                  None                                          None
# 24  ...                  None                                          None
# 25  ...                  None                                          None
# 26  ...                  None                                          None
# 27  ...                  None                                          None
# 28  ...                  None                                          None
# 29  ...                  None                                          None
# 30  ...                  None                                          None
# 31  ...                  None                                          None
# 32  ...                  None                                          None
# 33  ...                  None                                          None
# 34  ...                  None                                          None
# 35  ...                  None                                          None
# 36  ...                  None                                          None
# 37  ...                  None                                          None
# 38  ...                  None                                          None
# 39  ...                  None                                          None
# 40  ...                  None                                          None
# 41  ...                  None                                          None
# 42  ...                  None                                          None
# 43  ...                  None                                          None
# 44  ...                  None                                          None
# 45  ...                  None                                          None
# 46  ...                  None                                          None
# 47  ...                  None                                          None
# 48  ...                  None                                          None
# 49  ...                  None                                          None
#
#     Is this deal part of the Gov List?  Source from Market Researcher  \
# 0                             Gov List          ACRA, Google Searches
# 1                             Gov List          ACRA, Google Searches
# 2                             Gov List          ACRA, Google Searches
# 3                             Gov List          ACRA, Google Searches
# 4                             Gov List          ACRA, Google Searches
# 5                             Gov List          ACRA, Google Searches
# 6                             Gov List          ACRA, Google Searches
# 7                             Gov List          ACRA, Google Searches
# 8                             Gov List          ACRA, Google Searches
# 9                             Gov List          ACRA, Google Searches
# 10                            Gov List          ACRA, Google Searches
# 11                            Gov List          ACRA, Google Searches
# 12                            Gov List          ACRA, Google Searches
# 13                            Gov List          ACRA, Google Searches
# 14                            Gov List          ACRA, Google Searches
# 15                            Gov List          ACRA, Google Searches
# 16                            Gov List          ACRA, Google Searches
# 17                            Gov List          ACRA, Google Searches
# 18                            Gov List          ACRA, Google Searches
# 19                            Gov List          ACRA, Google Searches
# 20                            Gov List          ACRA, Google Searches
# 21                            Gov List          ACRA, Google Searches
# 22                            Gov List          ACRA, Google Searches
# 23                            Gov List          ACRA, Google Searches
# 24                            Gov List          ACRA, Google Searches
# 25                            Gov List          ACRA, Google Searches
# 26                            Gov List          ACRA, Google Searches
# 27                            Gov List          ACRA, Google Searches
# 28                            Gov List          ACRA, Google Searches
# 29                            Gov List          ACRA, Google Searches
# 30                            Gov List          ACRA, Google Searches
# 31                            Gov List          ACRA, Google Searches
# 32                            Gov List          ACRA, Google Searches
# 33                            Gov List          ACRA, Google Searches
# 34                            Gov List          ACRA, Google Searches
# 35                            Gov List          ACRA, Google Searches
# 36                            Gov List          ACRA, Google Searches
# 37                            Gov List          ACRA, Google Searches
# 38                            Gov List          ACRA, Google Searches
# 39                            Gov List          ACRA, Google Searches
# 40                            Gov List          ACRA, Google Searches
# 41                            Gov List          ACRA, Google Searches
# 42                            Gov List          ACRA, Google Searches
# 43                            Gov List          ACRA, Google Searches
# 44                            Gov List          ACRA, Google Searches
# 45                            Gov List          ACRA, Google Searches
# 46                            Gov List          ACRA, Google Searches
# 47                            Gov List          ACRA, Google Searches
# 48                            Gov List          ACRA, Google Searches
# 49                            Gov List          ACRA, Google Searches
#
#    Contact Number from Lusha? Phone number Verified ? Contact_Name  \
# 0                        None                    None          N/A
# 1                        None                    None          N/A
# 2                        None                    None          N/A
# 3                        None                    None          N/A
# 4                        None                    None          N/A
# 5                        None                    None          N/A
# 6                        None                    None          N/A
# 7                        None                    None          N/A
# 8                        None                    None          N/A
# 9                        None                    None          N/A
# 10                       None                    None          N/A
# 11                       None                    None          N/A
# 12                       None                    None          N/A
# 13                       None                    None          N/A
# 14                       None                    None          N/A
# 15                       None                    None          N/A
# 16                       None                    None          N/A
# 17                       None                    None          N/A
# 18                       None                    None          N/A
# 19                       None                    None          N/A
# 20                       None                    None          N/A
# 21                       None                    None          N/A
# 22                       None                    None          N/A
# 23                       None                    None          N/A
# 24                       None                    None          N/A
# 25                       None                    None          N/A
# 26                       None                    None          N/A
# 27                       None                    None          N/A
# 28                       None                    None          N/A
# 29                       None                    None          N/A
# 30                       None                    None          N/A
# 31                       None                    None          N/A
# 32                       None                    None          N/A
# 33                       None                    None          N/A
# 34                       None                    None          N/A
# 35                       None                    None          N/A
# 36                       None                    None          N/A
# 37                       None                    None          N/A
# 38                       None                    None          N/A
# 39                       None                    None          N/A
# 40                       None                    None          N/A
# 41                       None                    None          N/A
# 42                       None                    None          N/A
# 43                       None                    None          N/A
# 44                       None                    None          N/A
# 45                       None                    None          N/A
# 46                       None                    None          N/A
# 47                       None                    None          N/A
# 48                       None                    None   Eugene Tan
# 49                       None                    None          N/A
#
#                                        Contact_Title Contact_Number  \
# 0                                                N/A            N/A
# 1                                                N/A            N/A
# 2                                                N/A            N/A
# 3                                                N/A            N/A
# 4                                                N/A            N/A
# 5                                                N/A            N/A
# 6                                                N/A            N/A
# 7                                                N/A            N/A
# 8                                                N/A            N/A
# 9                                                N/A            N/A
# 10                                               N/A            N/A
# 11                                               N/A            N/A
# 12                                               N/A            N/A
# 13                                               N/A            N/A
# 14                                               N/A            N/A
# 15                                               N/A            N/A
# 16                                               N/A            N/A
# 17                                               N/A            N/A
# 18                                               N/A            N/A
# 19                                               N/A            N/A
# 20                                               N/A            N/A
# 21                                               N/A            N/A
# 22                                               N/A            N/A
# 23                                               N/A            N/A
# 24                                               N/A            N/A
# 25                                               N/A            N/A
# 26                                               N/A            N/A
# 27                                               N/A            N/A
# 28                                               N/A            N/A
# 29                                               N/A            N/A
# 30                                               N/A            N/A
# 31                                               N/A            N/A
# 32                                               N/A            N/A
# 33                                               N/A            N/A
# 34                                               N/A            N/A
# 35                                               N/A            N/A
# 36                                               N/A            N/A
# 37                                               N/A            N/A
# 38                                               N/A            N/A
# 39                                               N/A            N/A
# 40                                               N/A            N/A
# 41                                               N/A            N/A
# 42                                               N/A            N/A
# 43                                               N/A            N/A
# 44                                               N/A            N/A
# 45                                               N/A            N/A
# 46                                               N/A            N/A
# 47                                               N/A            N/A
# 48  Program Director of Supply Chain and Procurement  +65 9822 5164
# 49                                               N/A            N/A
#
#    Is_Decision_Maker
# 0                N/A
# 1                N/A
# 2                N/A
# 3                N/A
# 4                N/A
# 5                N/A
# 6                N/A
# 7                N/A
# 8                N/A
# 9                N/A
# 10               N/A
# 11               N/A
# 12               N/A
# 13               N/A
# 14               N/A
# 15               N/A
# 16               N/A
# 17               N/A
# 18               N/A
# 19               N/A
# 20               N/A
# 21               N/A
# 22               N/A
# 23               N/A
# 24               N/A
# 25               N/A
# 26               N/A
# 27               N/A
# 28               N/A
# 29               N/A
# 30               N/A
# 31               N/A
# 32               N/A
# 33               N/A
# 34               N/A
# 35               N/A
# 36               N/A
# 37               N/A
# 38               N/A
# 39               N/A
# 40               N/A
# 41               N/A
# 42               N/A
# 43               N/A
# 44               N/A
# 45               N/A
# 46               N/A
# 47               N/A
# 48               Yes
# 49               N/A
#
# [50 rows x 66 columns]

# %%
# Assign Lusha contacts to appropriate PIC columns based on availability
def assign_lusha_to_pic_columns(df):
    """
    Assign Lusha contact data to PIC columns intelligently:
    - If PIC NAME 1 Contact Number is empty -> assign to PIC 1 (First Name + Last Name)
    - Else if PIC NAME 2 Contact Number is empty -> assign to PIC 2 (First Name 2 + Last Name 2)
    - Else if PIC NAME 3 Contact Number is empty -> assign to PIC 3 (First Name 3 + Last Name 3)
    - Maintains matching between name and number columns
    - Removes '+' from phone numbers
    - Removes temporary Lusha columns after assignment
    """
    
    print("="*80)
    print("ASSIGNING LUSHA CONTACTS TO PIC COLUMNS")
    print("="*80)
    
    assigned_to_pic1 = 0
    assigned_to_pic2 = 0
    assigned_to_pic3 = 0
    skipped = 0
    
    for idx, row in df.iterrows():
        contact_name = row.get('Contact_Name', 'N/A')
        contact_title = row.get('Contact_Title', 'N/A')
        contact_number = row.get('Contact_Number', 'N/A')
        
        # Skip if no valid contact from Lusha
        if contact_number == 'N/A' or pd.isna(contact_number):
            skipped += 1
            continue
        
        # Clean phone number: Remove '+' and any leading/trailing spaces
        clean_number = str(contact_number).replace('+', '').strip()
        
        # Split name into first and last (simple split on first space)
        name_parts = contact_name.split(' ', 1) if contact_name != 'N/A' else ['N/A', '']
        first_name = name_parts[0]
        last_name = name_parts[1] if len(name_parts) > 1 else ''
        
        # Check PIC 1
        pic1_number = row.get('PIC NAME 1 Contact Number')
        if pd.isna(pic1_number) or pic1_number == '' or pic1_number == 'None':
            # Assign to PIC 1
            df.at[idx, 'First Name'] = first_name
            df.at[idx, 'Last Name'] = last_name
            df.at[idx, 'PIC Name 1 Designation'] = contact_title
            df.at[idx, 'PIC NAME 1 Contact Number'] = clean_number
            df.at[idx, 'Contact Number from Lusha?'] = 'Yes'
            assigned_to_pic1 += 1
            print(f"[PIC 1] {row['ACRA REGISTERED NAME'][:50]}: {contact_name} ({clean_number})")
            continue
        
        # Check PIC 2
        pic2_number = row.get('PIC NAME 2 Contact Number')
        if pd.isna(pic2_number) or pic2_number == '' or pic2_number == 'None':
            # Assign to PIC 2
            df.at[idx, 'First Name 2'] = first_name
            df.at[idx, 'Last Name 2'] = last_name
            df.at[idx, 'PIC Name 2 Designation'] = contact_title
            df.at[idx, 'PIC NAME 2 Contact Number'] = clean_number
            df.at[idx, 'Contact Number from Lusha?'] = 'Yes'
            assigned_to_pic2 += 1
            print(f"[PIC 2] {row['ACRA REGISTERED NAME'][:50]}: {contact_name} ({clean_number})")
            continue
        
        # Check PIC 3
        pic3_number = row.get('PIC NAME 3 Contact Number')
        if pd.isna(pic3_number) or pic3_number == '' or pic3_number == 'None':
            # Assign to PIC 3
            df.at[idx, 'First Name 3'] = first_name
            df.at[idx, 'Last Name 3'] = last_name
            df.at[idx, 'PIC Name Designation 3'] = contact_title
            df.at[idx, 'PIC NAME 3 Contact Number'] = clean_number
            df.at[idx, 'Contact Number from Lusha?'] = 'Yes'
            assigned_to_pic3 += 1
            print(f"[PIC 3] {row['ACRA REGISTERED NAME'][:50]}: {contact_name} ({clean_number})")
            continue
        
        # All PIC slots are full
        print(f"[SKIP] {row['ACRA REGISTERED NAME'][:50]}: All PIC slots full")
        skipped += 1
    
    print(f"\n{'='*80}")
    print(f"ASSIGNMENT SUMMARY:")
    print(f"  Assigned to PIC 1: {assigned_to_pic1}")
    print(f"  Assigned to PIC 2: {assigned_to_pic2}")
    print(f"  Assigned to PIC 3: {assigned_to_pic3}")
    print(f"  Skipped (no contact or slots full): {skipped}")
    print(f"{'='*80}\n")
    
    return df

# Apply the assignment
companies_df = assign_lusha_to_pic_columns(companies_df)

# Show the updated PIC columns BEFORE cleanup
print("\nUPDATED PIC COLUMNS:")
print("="*80)
pic_cols = [
    'ACRA REGISTERED NAME',
    'First Name', 'Last Name', 'PIC Name 1 Designation', 'PIC NAME 1 Contact Number',
    'First Name 2', 'Last Name 2', 'PIC Name 2 Designation', 'PIC NAME 2 Contact Number',
    'First Name 3', 'Last Name 3', 'PIC Name Designation 3', 'PIC NAME 3 Contact Number',
    'Contact Number from Lusha?'
]
print(companies_df[pic_cols].to_string(index=False))

# Remove temporary Lusha columns
print("\n" + "="*80)
print("CLEANING UP TEMPORARY COLUMNS")
print("="*80)

lusha_temp_cols = ['Contact_Name', 'Contact_Title', 'Contact_Number', 'Is_Decision_Maker']
existing_temp_cols = [col for col in lusha_temp_cols if col in companies_df.columns]

if existing_temp_cols:
    companies_df = companies_df.drop(columns=existing_temp_cols)
    print(f"Removed temporary columns: {', '.join(existing_temp_cols)}")
else:
    print("No temporary columns to remove")

print(f"\nFinal DataFrame shape: {companies_df.shape}")
print(f"Final columns count: {len(companies_df.columns)}")

# %%
companies_df.columns.tolist()

# %%
companies_df_x = companies_df[["First Name", "Last Name", "PIC NAME 1 Contact Number","First Name 2", "Last Name 2", "PIC NAME 2 Contact Number"]]
companies_df_x

# %%
# companies_df.to_csv("./new_leads.csv")

# %%
# import requests
# import pandas as pd
# import time

# # API Configuration
# API_KEY = "15304a36-d527-4f30-b250-b79cd409a464"
# BASE_URL = "https://api.lusha.com"
# CONTACT_SEARCH_ENDPOINT = f"{BASE_URL}/prospecting/contact/search"
# CONTACT_ENRICH_ENDPOINT = f"{BASE_URL}/prospecting/contact/enrich"

# headers = {
#     "api_key": API_KEY,
#     "Content-Type": "application/json"
# }

# # OPTIMIZED: Search all companies at once instead of one-by-one
# def search_all_companies_optimized(company_names, batch_size=40):
#     """
#     Search for contacts across ALL companies in batches to minimize credit usage
    
#     Instead of 1 credit per company, we search in batches of up to 40 companies
#     for 1 credit per batch (up to 40 results)
    
#     Parameters:
#     - company_names: list of company names
#     - batch_size: max results per search (default 40, max before next page)
    
#     Returns:
#     - Dictionary mapping company name to list of contacts
#     """
#     all_contacts_by_company = {}
#     total_credits = 0
    
#     # Process companies in batches
#     for batch_start in range(0, len(company_names), batch_size):
#         batch = company_names[batch_start:batch_start + batch_size]
        
#         print(f"\n{'='*80}")
#         print(f"BATCH {batch_start//batch_size + 1}: Searching {len(batch)} companies in ONE request")
#         print(f"{'='*80}")
        
#         # Search for ALL companies in this batch at once
#         payload = {
#             "pages": {"page": 0, "size": batch_size},
#             "filters": {
#                 "contacts": {
#                     "include": {"existing_data_points": ["phone", "mobile_phone"]}
#                 },
#                 "companies": {
#                     "include": {"names": batch}  # Search multiple companies at once!
#                 }
#             }
#         }
        
#         try:
#             response = requests.post(CONTACT_SEARCH_ENDPOINT, headers=headers, json=payload)
            
#             if response.status_code in [200, 201]:
#                 data = response.json()
#                 contacts = data.get('data', [])
#                 request_id = data.get('requestId', '')
#                 credits = data.get('billing', {}).get('creditsCharged', 0)
#                 total_credits += credits
                
#                 print(f"✓ Found {len(contacts)} total contacts across {len(batch)} companies")
#                 print(f"✓ Credits charged: {credits} (vs {len(batch)} if searched individually)")
#                 print(f"✓ Savings: {len(batch) - credits} credits!")
                
#                 # Group contacts by company
#                 for contact in contacts:
#                     company = contact.get('companyName', '')
#                     if company not in all_contacts_by_company:
#                         all_contacts_by_company[company] = []
#                     all_contacts_by_company[company].append({
#                         'contact': contact,
#                         'request_id': request_id
#                     })
                
#                 time.sleep(0.1)
#             else:
#                 print(f"✗ Search Error {response.status_code}")
        
#         except Exception as e:
#             print(f"✗ Exception: {str(e)}")
    
#     print(f"\n{'='*80}")
#     print(f"💳 Total search credits used: {total_credits} (vs {len(company_names)} individual searches)")
#     print(f"💰 Credit savings: {len(company_names) - total_credits}")
#     print(f"{'='*80}\n")
    
#     return all_contacts_by_company, total_credits

# # Function to enrich contacts
# def enrich_contacts_batch(request_id, contact_ids):
#     """Enrich multiple contacts at once"""
#     if not contact_ids:
#         return {}
    
#     enrich_payload = {
#         "requestId": request_id,
#         "contactIds": contact_ids
#     }
    
#     try:
#         response = requests.post(CONTACT_ENRICH_ENDPOINT, headers=headers, json=enrich_payload)
        
#         if response.status_code in [200, 201]:
#             data = response.json()
            
#             phone_map = {}
#             if data.get('contacts') and isinstance(data['contacts'], list):
#                 for contact in data['contacts']:
#                     contact_id = contact.get('id') or contact.get('contactId')
#                     phones = contact.get('data', {}).get('phoneNumbers', [])
                    
#                     if phones and len(phones) > 0:
#                         phone_map[contact_id] = phones[0].get('number', 'N/A')
#                     else:
#                         phone_map[contact_id] = 'N/A'
            
#             return phone_map
#         else:
#             print(f"  Enrich Error {response.status_code}")
#             return {}
    
#     except Exception as e:
#         print(f"  Enrich Exception: {str(e)}")
#         return {}

# # Main optimized function
# def get_company_contacts_optimized(companies_df):
#     """
#     OPTIMIZED: Get first contact for each company with minimal credit usage
#     """
#     company_names = companies_df['ACRA REGISTERED NAME'].tolist()
    
#     # Step 1: Search all companies in batches (1 credit per 40 companies instead of 1 per company!)
#     contacts_by_company, search_credits = search_all_companies_optimized(company_names, batch_size=40)
    
#     # Step 2: Enrich only the first contact per company
#     results = []
#     enrich_credits = 0
    
#     print("\n" + "="*80)
#     print("ENRICHING FIRST CONTACT PER COMPANY")
#     print("="*80)
    
#     for company_name in company_names:
#         # Find matching company (case-insensitive partial match)
#         matched_company = None
#         for key in contacts_by_company.keys():
#             if company_name.upper() in key.upper() or key.upper() in company_name.upper():
#                 matched_company = key
#                 break
        
#         if matched_company and contacts_by_company[matched_company]:
#             contact_data = contacts_by_company[matched_company][0]
#             contact = contact_data['contact']
#             request_id = contact_data['request_id']
            
#             contact_id = contact.get('contactId')
#             contact_name = contact.get('name', 'N/A')
#             contact_title = contact.get('jobTitle', 'N/A')
            
#             print(f"\n{company_name}:")
#             print(f"  → {contact_name} ({contact_title})")
            
#             # Enrich to get phone
#             if contact_id and request_id:
#                 phone_map = enrich_contacts_batch(request_id, [contact_id])
#                 phone_number = phone_map.get(contact_id, 'N/A')
#                 enrich_credits += 1
                
#                 if phone_number and phone_number != 'N/A':
#                     print(f"  ✓ Phone: {phone_number}")
#                 else:
#                     print(f"  ✗ No phone available")
#             else:
#                 phone_number = 'N/A'
            
#             results.append({
#                 'Company': company_name,
#                 'First_Contact_Name': contact_name,
#                 'First_Contact_Title': contact_title,
#                 'First_Contact_Number': phone_number
#             })
            
#             time.sleep(0.1)
#         else:
#             print(f"\n{company_name}: No contacts found")
#             results.append({
#                 'Company': company_name,
#                 'First_Contact_Name': 'N/A',
#                 'First_Contact_Title': 'N/A',
#                 'First_Contact_Number': 'N/A'
#             })
    
#     print(f"\n{'='*80}")
#     print(f"💳 TOTAL CREDITS USED:")
#     print(f"   Search: {search_credits} credits")
#     print(f"   Enrich: {enrich_credits} credits")
#     print(f"   Total: {search_credits + enrich_credits} credits")
#     print(f"\n💰 SAVINGS vs individual search: {len(company_names) - search_credits} credits!")
#     print(f"{'='*80}\n")
    
#     return pd.DataFrame(results)

# # Run optimized version
# print("="*80)
# print("OPTIMIZED COMPANY CONTACT SEARCH")
# print("="*80)

# results_df = get_company_contacts_optimized(companies_df)

# print("\nFINAL RESULTS:")
# print("="*80)
# print(results_df.to_string(index=False))

# # Add to dataframe
# companies_df['First_Contact_Name'] = results_df['First_Contact_Name']
# companies_df['First_Contact_Title'] = results_df['First_Contact_Title']
# companies_df['First_Contact_Number'] = results_df['First_Contact_Number']

# print("\n\nUPDATED DATAFRAME:")
# print("="*80)
# companies_df

# %%
# import requests
# import pandas as pd
# import time

# # Assuming you have companies_df loaded already
# # For demo purposes, let's load it from the Bronze parquet file
# # companies_df = pd.read_parquet("./Staging/Bronze/bronze_data_1.parquet", engine="fastparquet")
 
# # API Configuration
# API_KEY = "15304a36-d527-4f30-b250-b79cd409a464"
# BASE_URL = "https://api.lusha.com"
# CONTACT_SEARCH_ENDPOINT = f"{BASE_URL}/prospecting/contact/search"

# headers = {
#     "api_key": API_KEY,
#     "Content-Type": "application/json"
# }

# # Get the first company name from companies_df
# # Assuming companies_df is already loaded in your notebook
# company_name = companies_df['ACRA REGISTERED NAME'].iloc[0]
# print(f"Searching for contacts at: {company_name}\n")

# # Prepare the search payload
# # NOTE: Lusha API requires minimum page size of 10
# search_payload = {
#     "pages": {
#         "page": 0,
#         "size": 10  # Minimum required by Lusha API
#     },
#     "filters": {
#         "contacts": {
#             "include": {
#                 "existing_data_points": ["phone", "mobile_phone"]  # Only contacts with phone numbers
#             }
#         },
#         "companies": {
#             "include": {
#                 "names": [company_name]  # Search by company name
#             }
#         }
#     }
# }

# # Make the API request
# response = requests.post(CONTACT_SEARCH_ENDPOINT, headers=headers, json=search_payload)

# # Check response - Lusha returns 201 (Created) for successful searches
# if response.status_code in [200, 201]:
#     data = response.json()
#     total_found = len(data.get('data', []))
#     print(f"✓ Success! Found {total_found} contacts")
#     print(f"Credits charged: {data.get('billing', {}).get('creditsCharged', 'N/A')}\n")
    
#     # Extract contact information (limit to first 5)
#     contacts = []
#     for contact in data.get('data', [])[:5]:  # Take only first 5
#         contact_info = {
#             'Name': contact.get('name', 'N/A'),
#             'Title': contact.get('jobTitle', 'N/A'),
#             'Company': contact.get('companyName', company_name),
#             'Phone': 'Available' if contact.get('hasPhones') else 'N/A',
#             'Mobile': 'Available' if contact.get('hasMobilePhone') else 'N/A',
#             'Email': 'Available' if contact.get('hasEmails') else 'N/A',
#             'Contact_ID': contact.get('contactId', 'N/A')
#         }
#         contacts.append(contact_info)
    
#     # Create DataFrame
#     contacts_df = pd.DataFrame(contacts)
#     print(f"Showing first {len(contacts)} contacts:\n")
#     print(contacts_df.to_string(index=False))
    
# else:
#     print(f"✗ Error {response.status_code}: {response.text}")

# print("\n" + "="*80 + "\n")

# # Function to search contacts for multiple companies
# def search_company_contacts(company_names, max_contacts_to_show=5):
#     """
#     Search for contacts across multiple companies
    
#     Parameters:
#     - company_names: list of company names from ACRA_REGISTERED_NAME column
#     - max_contacts_to_show: number of contacts to return per company (will request 10 from API, show this many)
    
#     Returns:
#     - DataFrame with all contacts found
#     """
#     all_contacts = []
    
#     for idx, company_name in enumerate(company_names, 1):
#         print(f"[{idx}/{len(company_names)}] Searching: {company_name}")
        
#         payload = {
#             "pages": {
#                 "page": 0,
#                 "size": 10  # Minimum required by Lusha API
#             },
#             "filters": {
#                 "contacts": {
#                     "include": {
#                         "existing_data_points": ["phone", "mobile_phone"]
#                     }
#                 },
#                 "companies": {
#                     "include": {
#                         "names": [company_name]
#                     }
#                 }
#             }
#         }
        
#         try:
#             response = requests.post(CONTACT_SEARCH_ENDPOINT, headers=headers, json=payload)
            
#             # Lusha returns 201 (Created) for successful searches
#             if response.status_code in [200, 201]:
#                 data = response.json()
#                 contacts_found = data.get('data', [])
                
#                 # Take only the number requested
#                 for contact in contacts_found[:max_contacts_to_show]:
#                     contact_info = {
#                         'Company': contact.get('companyName', company_name),
#                         'Name': contact.get('name', 'N/A'),
#                         'Title': contact.get('jobTitle', 'N/A'),
#                         'Has_Phone': 'Yes' if contact.get('hasPhones') else 'No',
#                         'Has_Mobile': 'Yes' if contact.get('hasMobilePhone') else 'No',
#                         'Has_Email': 'Yes' if contact.get('hasEmails') else 'No',
#                         'Contact_ID': contact.get('contactId', 'N/A'),
#                         'Person_ID': contact.get('personId', 'N/A')
#                     }
#                     all_contacts.append(contact_info)
                
#                 credits = data.get('billing', {}).get('creditsCharged', 0)
#                 print(f"  ✓ Found {len(contacts_found)} contacts (showing {min(len(contacts_found), max_contacts_to_show)}) - Credits: {credits}")
#             else:
#                 print(f"  ✗ Error {response.status_code}: {response.text}")
        
#         except Exception as e:
#             print(f"  ✗ Exception: {str(e)}")
        
#         # Rate limiting: 25 requests per second max, so add small delay
#         time.sleep(0.05)
    
#     return pd.DataFrame(all_contacts)

# # Example: Search for contacts from first 3 companies in companies_df
# print("Searching multiple companies...")
# print("="*80)
# company_list = companies_df['ACRA REGISTERED NAME'].head(3).tolist()
# results_df = search_company_contacts(company_list, max_contacts_to_show=5)

# print("\n" + "="*80)
# print(f"\nTotal contacts found: {len(results_df)}")
# print("\nResults:")
# print(results_df.to_string(index=False))
