# %%
import requests
import pandas as pd
import numpy as np
import glob
import os
import re
from langchain.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from apify_client import ApifyClient

# Initialize the ApifyClient with your API token
client = ApifyClient("apify_api_yNR85etaHpLtBzPoVozVVXUsCZe54u2Ffog1")

# Prepare the Actor input
# Allowed seniority_level values: "founder", "owner", "c_suite", "director", "partner", "vp", "head", "manager", "senior", "entry", "trainee"
# Note: All location/city/industry values must be lowercase
run_input = {
    "fetch_count": 5,
    "file_name": "Prospects",
    "contact_job_title": ["manager"],
    "contact_not_job_title": ["marketing"],
    "seniority_level": ["manager", "director", "head"],
    "contact_location": ["singapore"],
    "contact_city": ["singapore"],
    "contact_not_location": ["malaysia"],
    "contact_not_city": ["kuala lumpur"],
    "email_status": ["validated"],
    "company_industry": ["wholesale"],
}

# Run the Actor and wait for it to finish
run = client.actor("IoSHqwTR9YGhzccez").call(run_input=run_input)

# Fetch and print Actor results from the run's dataset (if there are any)
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    print(item)
# Out:
# [apify.leads-finder runId:zzQge6yxY7DmdRhqO] -> Status: RUNNING, Message:
# [apify.leads-finder runId:zzQge6yxY7DmdRhqO] -> 2025-11-03T08:31:18.261Z ACTOR: Pulling container image of build qXieb12LtBh23XccI from registry.
# [apify.leads-finder runId:zzQge6yxY7DmdRhqO] -> 2025-11-03T08:31:18.263Z ACTOR: Creating container.
# [apify.leads-finder runId:zzQge6yxY7DmdRhqO] -> 2025-11-03T08:31:18.347Z ACTOR: Starting container.
# [apify.leads-finder runId:zzQge6yxY7DmdRhqO] -> 2025-11-03T08:31:19.498Z INFO  System info {"apifyVersion":"3.5.0","apifyClientVersion":"2.17.0","crawleeVersion":"3.15.1","osType":"Linux","nodeVersion":"v22.20.0"}
# [apify.leads-finder runId:zzQge6yxY7DmdRhqO] -> 2025-11-03T08:31:19.620Z INFO  🚀 Starting Leads Finder Actor...
# [apify.leads-finder runId:zzQge6yxY7DmdRhqO] -> 2025-11-03T08:31:19.886Z INFO  ❌ Users on the free Apify plan can run the actor through the UI and not via other methods.
# ...
