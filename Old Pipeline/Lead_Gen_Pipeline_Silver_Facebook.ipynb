# %% [markdown]
# ### Data Mining Facebook (Silver 2)

# %%
import os
import requests
import aiohttp
import asyncio
import nest_asyncio
import pandas as pd
import time
import scrapy
from scrapy_playwright.page import PageMethod
from bs4 import BeautifulSoup
import nest_asyncio
import glob
import numpy as np
import matplotlib.pyplot as plt
from fuzzywuzzy import fuzz, process
import re
from apify_client import ApifyClient

# %% [markdown]
# ### Ingest Data

# %%
import os
import pandas as pd

# --- Load Parquet ---
parquet_path = "./Staging/Silver/carmotor_facebook_only.parquet"
if os.path.exists(parquet_path):
    facebook_only_df = pd.read_parquet(parquet_path, engine="fastparquet")
    print(f"Loaded {len(facebook_only_df)} rows from {parquet_path}")
    print(facebook_only_df.shape)
else:
    raise FileNotFoundError(f"Parquet file not found at {parquet_path}")

# --- Filter rows where Facebook is not None/NaN ---
facebook_only_df = facebook_only_df[facebook_only_df["Facebook"].notna()]

# --- Clean the existing Facebook column in-place ---
def clean_facebook(x):
    if isinstance(x, list):                  # if it's a list
        return x[0] if len(x) > 0 else None  # take first URL or None
    elif pd.isna(x):                          # if NaN
        return None
    else:                                     # already a string
        return x

facebook_only_df["Facebook"] = facebook_only_df["Facebook"].apply(clean_facebook)

# --- Remove empty or None values after cleaning ---
facebook_only_df = facebook_only_df[facebook_only_df["Facebook"].notna() & (facebook_only_df["Facebook"] != "")]

# --- Inspect cleaned data ---
facebook_only_df.head()
# Out:
# Loaded 47 rows from ./Staging/Silver/carmotor_facebook_only.parquet
# (47, 16)
#           UEN   Status Error                     Emails Phones  \
# 0  202503911K  success  None                       None   None
# 1  202412050W  success  None                       None   None
# 2   53459382L  success  None                       None   None
# 3   53471316E  success  None     [admin@xgarage.com.my]   None
# 4   53427200B  success  None  [3hautotrading@gmail.com]   None
#
#                                              Website  \
# 0                                               None
# 1  https://www.classicmotorworks.com.sg/?utm_sour...
# 2                                               None
# 3                            https://xgarage.com.my/
# 4                                               None
#
#                                        Facebook LinkedIn  \
# 0   https://www.facebook.com/thedetailingcoltd/     None
# 1  https://www.facebook.com/classicmotorworkssg     None
# 2        https://m.facebook.com/100090788316126     None
# 3      https://www.facebook.com/xgarage.xgarage     None
# 4       https://www.facebook.com/3HAutoTrading/     None
#
#                                           Instagram TikTok  \
# 0       [https://www.instagram.com/detailingco.pk/]   None
# 1  [https://www.instagram.com/classicmotorworkssg/]   None
# 2                                              None   None
# 3            [https://www.instagram.com/x.garage_/]   None
# 4                                              None   None
#
#                                       RecordOwl_Link  \
# 0  https://recordowl.com/company/the-detailingco-...
# 1  https://recordowl.com/company/jinson-garage-pt...
# 2    https://recordowl.com/company/vegas-motor-works
# 3             https://recordowl.com/company/x-garage
# 4      https://recordowl.com/company/3h-auto-trading
#
#                                   operational_street operational_unit  \
# 0         61 WOODLANDS INDUSTRIAL PARK E9 E9 PREMIUM            01-20
# 1                    60 JALAN LAM HUAT CARROS CENTRE            05-58
# 2  9002 TAMPINES STREET 93 TAMPINES INDUSTRIAL PA...            01-40
# 3            15 KAKI BUKIT ROAD 4 BARTLEY BIZ CENTRE            01-53
# 4               192 PANDAN LOOP PANTECH BUSINESS HUB            07-23
#
#   operational_postal_code                                operational_address  \
# 0                  757047  61 WOODLANDS INDUSTRIAL PARK E9 E9 PREMIUM 01-...
# 1                  737869  60 JALAN LAM HUAT CARROS CENTRE 05-58 Singapor...
# 2                  528836  9002 TAMPINES STREET 93 TAMPINES INDUSTRIAL PA...
# 3                  417808  15 KAKI BUKIT ROAD 4 BARTLEY BIZ CENTRE 01-53 ...
# 4                  128381  192 PANDAN LOOP PANTECH BUSINESS HUB 07-23 Sin...
#
#   Phones_str
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None

# %%
# parquet_path = "./Staging/Gold/cleaned_second_592.parquet"
# if os.path.exists(parquet_path):
#     RecordOwl_Leads = pd.read_parquet(parquet_path, engine="fastparquet")
#     print(f"Loaded {len(RecordOwl_Leads)} rows from {parquet_path}")
#     print(RecordOwl_Leads.shape)
# else:
#     raise FileNotFoundError(f"Parquet file not found at {parquet_path}")


# filtered_df = RecordOwl_Leads[
#     (RecordOwl_Leads["Facebook Page"].notna()) & 
#     (RecordOwl_Leads["Facebook Page"] != "") &
#     (RecordOwl_Leads["PIC NAME 1 Contact Number"].isna() | 
#      (RecordOwl_Leads["PIC NAME 1 Contact Number"] == ""))
# ].copy()

# # filtered_df = filtered_df[["PIC NAME 1 Contact Number", "Facebook Page"]]
# facebook_only_df = filtered_df.copy() 
# facebook_only_df.shape

# %%
# Initialize the ApifyClient with your API token
client = ApifyClient("apify_api_gak2ulhepgd4uzBseSLQtiHnb9KGxy3iMwp2")

BATCH_SIZE = 100  # Process 50 Facebook pages per batch (5x increase from 10)
MAX_CONCURRENCY = 3  # Scrape 3 pages simultaneously for stable performance

def validate_singapore_number(phone):
    """Validates and standardizes Singapore phone numbers."""
    if not phone:
        return None
    cleaned = re.sub(r'[\s\-\(\)\.\|/]', '', str(phone))
    if cleaned.startswith('+'):
        cleaned = cleaned[1:]
    if cleaned.startswith('65'):
        number_part = cleaned[2:]
        if re.match(r'^[689]\d{7}$', number_part):
            return f"+65{number_part}"
    elif re.match(r'^[689]\d{7}$', cleaned):
        return f"+65{cleaned}"
    return None


def run_facebook_scraper_batch(client, facebook_urls_batch):
    """Run Apify Facebook scraper for a batch of URLs."""
    
    print(f"\n  Batch URLs ({len(facebook_urls_batch)} pages):")
    for i, url in enumerate(facebook_urls_batch, 1):
        display_url = url if len(url) <= 60 else url[:57] + "..."
        print(f"      {i}. {display_url}")
    
    # Exact format from working reference code
    run_input = {
        "pages": facebook_urls_batch,
        "language": "en-US",
    }

    print(f"\n  Launching Apify actor (batch of {len(facebook_urls_batch)}, concurrency: {MAX_CONCURRENCY})...")
    print(f"  Estimated cost: ${0.006 + (len(facebook_urls_batch) * 0.013):.4f} USD")
    
    try:
        run = client.actor("oJ48ceKNY7ueGPGL0").call(run_input=run_input)
        
        print(f"  Run ID: {run['id']}")
        print(f"  Status: {run.get('status', 'RUNNING')}")
        
        results = []
        for item in client.dataset(run["defaultDatasetId"]).iterate_items():
            results.append(item)
        
        print(f"  Retrieved {len(results)}/{len(facebook_urls_batch)} results from batch")
        return results, None
        
    except Exception as e:
        print(f"  Batch error: {str(e)}")
        return [], str(e)


# Process all rows
if len(facebook_only_df) > 0:
    print("=" * 80)
    print(f"FACEBOOK SCRAPER - MAXIMUM COST OPTIMIZATION (50-Batch Config)")
    print("=" * 80)
    print(f"Total Facebook pages: {len(facebook_only_df)}")
    print(f"Batch size: {BATCH_SIZE} pages per batch")
    print(f"Concurrency: {MAX_CONCURRENCY} pages scraped simultaneously per batch")
    
    # Calculate cost savings
    num_batches_50 = (len(facebook_only_df) + 49) // 50
    num_batches_10 = (len(facebook_only_df) + 9) // 10
    startup_cost_50 = num_batches_50 * 0.006
    startup_cost_10 = num_batches_10 * 0.006
    savings_pct = ((startup_cost_10 - startup_cost_50) / startup_cost_10 * 100) if startup_cost_10 > 0 else 0
    
    print(f"Estimated total cost: ${(len(facebook_only_df) // BATCH_SIZE + 1) * 0.006 + len(facebook_only_df) * 0.013:.4f} USD")
    print(f"\nCost Optimization vs 10-Batch Config:")
    print(f"   {savings_pct:.0f}% fewer actor runs ({num_batches_50} vs {num_batches_10} batches)")
    print(f"   Startup cost savings: ${startup_cost_10 - startup_cost_50:.4f} USD")
    print("=" * 80)
    
    total_successful = 0
    total_failed = 0
    total_phones_found = 0
    total_cost_estimate = 0.0
    
    total_rows = len(facebook_only_df)
    num_batches = (total_rows + BATCH_SIZE - 1) // BATCH_SIZE
    
    for batch_idx in range(0, total_rows, BATCH_SIZE):
        batch = facebook_only_df.iloc[batch_idx:batch_idx + BATCH_SIZE]
        facebook_urls = [str(row['Facebook']).strip() for _, row in batch.iterrows()]
        batch_indices = list(batch.index)
        
        print(f"\n{'-'*80}")
        print(f"Batch {(batch_idx//BATCH_SIZE)+1}/{num_batches}")
        
        items, error = run_facebook_scraper_batch(client, facebook_urls)
        
        batch_cost = 0.006 + (len(facebook_urls) * 0.013)
        total_cost_estimate += batch_cost
        
        if error:
            print(f"  Batch failed, marking all {len(batch_indices)} pages as None")
            for idx in batch_indices:
                facebook_only_df.loc[idx, 'Phones'] = None
            total_failed += len(batch_indices)
            continue
        
        # Map results back to dataframe
        url_to_item = {}
        for item in items:
            fb_url = item.get('facebookUrl') or item.get('url') or item.get('pageUrl')
            if fb_url:
                normalized_url = fb_url.lower().strip().rstrip('/')
                url_to_item[normalized_url] = item
        
        print(f"\n  Processing batch results:")
        for idx, row in batch.iterrows():
            original_url = str(row['Facebook']).strip()
            normalized_search = original_url.lower().strip().rstrip('/')
            
            item = url_to_item.get(normalized_search)
            
            if item:
                raw_phone = item.get('phone', None) or item.get('wa_number', None) or item.get('mobile', None)
                phone = validate_singapore_number(raw_phone)
                
                if phone:
                    facebook_only_df.loc[idx, 'Phones'] = phone
                    print(f"    OK {original_url[:50]}... -> {phone}")
                    total_phones_found += 1
                    total_successful += 1
                else:
                    facebook_only_df.loc[idx, 'Phones'] = None
                    print(f"    WARN {original_url[:50]}... -> No valid SG number found")
                    total_successful += 1
            else:
                facebook_only_df.loc[idx, 'Phones'] = None
                print(f"    FAIL {original_url[:50]}... -> Not found in results")
                total_failed += 1
        
        if batch_idx + BATCH_SIZE < total_rows:
            print(f"\n  Waiting 3 seconds before next batch...")
            time.sleep(3)
    
    print("\n" + "=" * 80)
    print("FINAL SCRAPING SUMMARY:")
    print("=" * 80)
    print(f"  Total pages processed: {total_rows}")
    print(f"  Successful scrapes: {total_successful}")
    print(f"  Failed scrapes: {total_failed}")
    print(f"  Valid phone numbers found: {total_phones_found}")
    print(f"  Success rate: {(total_successful/total_rows)*100:.1f}%")
    print(f"  Phone found rate: {(total_phones_found/total_rows)*100:.1f}%")
    print(f"  Estimated cost: ${total_cost_estimate:.4f} USD")
    print(f"  Cost per phone found: ${total_cost_estimate/total_phones_found:.4f} USD" if total_phones_found > 0 else "  Cost per phone: N/A")
    print("=" * 80)
    
    display(facebook_only_df)
    
else:
    print("No data available in facebook_only_df")

# %%
df_with_phones = facebook_only_df[facebook_only_df["Phones"].notna()]

print(df_with_phones["Phones"].is_unique)
# Out:
# True

# %%
df_with_phones = facebook_only_df[facebook_only_df["Phones"].notna()]
df_without_phones = facebook_only_df[facebook_only_df["Phones"].isna()]

# Store unique phone numbers inside final_df_1
final_df_1 = df_with_phones[df_with_phones["Phones"].duplicated(keep=False) == False]

# Store duplicate phone numbers inside refilter_df_1
refilter_df_1 = df_with_phones[df_with_phones["Phones"].duplicated(keep=False) == True]

# %%
df_without_phones_2 = pd.concat([refilter_df_1, df_without_phones], ignore_index=True)
df_without_phones_2.shape

# %%
df_without_phones_2
# Out:
#            UEN   Status Error                                   Emails Phones  \
# 0   202503911K  success  None                                     None   None
# 1    53459382L  success  None                                     None   None
# 2    53471316E  success  None                   [admin@xgarage.com.my]   None
# 3    53466996D  success  None                                     None   None
# 4    53482722E  success  None                                     None   None
# 5    53448674J  success  None            [superjservicesltd@gmail.com]   None
# 6    53431738C  success  None                                     None   None
# 7    53484790X  success  None  [apexmotorworksandretoration@yahoo.com]   None
# 8   202505190W  success  None                                     None   None
# 9    53476477X  success  None                                     None   None
# 10   53408224J  success  None            [manager@ezcruiseparking.com]   None
# 11   53434305L  success  None            [ecodieseldynamics@gmail.com]   None
# 12   53464227J  success  None                        [info@cartesy.de]   None
# 13  202012242C  success  None            [tommy@jssmautosolutions.com]   None
# 14  202227809C  success  None                                     None   None
# 15   53482117X  success  None                [jason@9kmotorsports.com]   None
# 16   53468383E  success  None                                     None   None
# 17   53465601C  success  None                                     None   None
# 18   53441811B  success  None                                     None   None
# 19  202038219N  success  None                                     None   None
# 20   53447499C  success  None          [ctkautomotivesdnbhd@gmail.com]   None
# 21   53414364D  success  None                                     None   None
# 22  202343910E  success  None  [sales@rtac-consulting-engineering.com]   None
# 23  202410643M  success  None                                     None   None
# 24  202238655G  success  None                                     None   None
# 25  202414582D  success  None                                     None   None
# 26   53468738E  success  None               [Info@freshautocare.co.uk]   None
# 27  202237384N  success  None                                     None   None
# 28  202203848Z  success  None                                     None   None
# 29  202342246K  success  None                                     None   None
# 30  202514392K  success  None                 [info@masev-designs.com]   None
# 31  202500469Z  success  None                                     None   None
#
#                                               Website  \
# 0                                                None
# 1                                                None
# 2                             https://xgarage.com.my/
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11        https://ecodieseldynamics.com/diesel-parts/
# 12                                               None
# 13  https://www.mycareersfuture.gov.sg/job/manufac...
# 14                             https://g7workshop.sg/
# 15                              https://9kmotors.com/
# 16                          https://genushair.com/en/
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22           https://rtac-consulting-engineering.com/
# 23                                               None
# 24                                               None
# 25                                               None
# 26                       https://freshautocare.co.uk/
# 27                                               None
# 28                                               None
# 29                         https://www.trans-tec.com/
# 30           https://masev-designs.com/contactus.html
# 31                           https://detailogy.co.uk/
#
#                                              Facebook  \
# 0         https://www.facebook.com/thedetailingcoltd/
# 1              https://m.facebook.com/100090788316126
# 2            https://www.facebook.com/xgarage.xgarage
# 3   https://www.facebook.com/p/RMS-Motors-10006972...
# 4         https://www.facebook.com/PJsGarageLimerick/
# 5           https://www.facebook.com/treesurgeonBath/
# 6   https://www.facebook.com/AtatcutzAppointment/p...
# 7              https://m.facebook.com/61556350627595/
# 8         https://www.facebook.com/Ignite%20Autowerkz
# 9   https://www.facebook.com/p/YL-Car-Accessories-...
# 10           https://www.facebook.com/EzCruiseParking
# 11         https://www.facebook.com/ecodieseldynamics
# 12  https://www.facebook.com/people/Cartesy-GmbH/6...
# 13        https://www.facebook.com/jssmautosolutions/
# 14              https://www.facebook.com/g7workshopsg
# 15            https://www.facebook.com/61568245975495
# 16           https://www.facebook.com/genushairitalia
# 17        https://www.facebook.com/LkautoAccessories/
# 18  https://www.facebook.com/people/Levi-Automotiv...
# 19    https://www.facebook.com/krtfoods/?locale=sr_RS
# 20      https://www.facebook.com/CTKAutoMotiveSDNBHD/
# 21  https://facebook.com/JA-Auto-Workshop-21512741...
# 22           https://www.facebook.com/rtacconsulting/
# 23  https://www.facebook.com/Singalife?mibextid=LQ...
# 24        https://www.facebook.com/leeshengautopteltd
# 25            https://www.facebook.com/61559843622239
# 26          https://www.facebook.com/freshautocareuk/
# 27  https://www.facebook.com/people/JIN-WANG-Autom...
# 28  https://www.facebook.com/p/Buddy-Spray-1000823...
# 29  https://www.facebook.com/profile.php?id=615658...
# 30                  https://www.facebook.com/masev3d/
# 31                https://www.facebook.com/detailogy/
#
#                                              LinkedIn  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4   [https://ie.linkedin.com/in/paul-hoffmann-2889...
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10  [https://www.linkedin.com/in/cynthia-tompkins-...
# 11                                               None
# 12     [https://de.linkedin.com/company/cartesy-gmbh]
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
#
#                                             Instagram TikTok  \
# 0         [https://www.instagram.com/detailingco.pk/]   None
# 1                                                None   None
# 2              [https://www.instagram.com/x.garage_/]   None
# 3             [https://www.instagram.com/rms.motors/]   None
# 4   [https://www.instagram.com/pjgarage/, https://...   None
# 5      [https://www.instagram.com/tree_surgeon_bath/]   None
# 6                                                None   None
# 7                                                None   None
# 8         [https://www.instagram.com/igniteautowerkz]   None
# 9                                                None   None
# 10                                               None   None
# 11                                               None   None
# 12           [https://www.instagram.com/cartesygmbh/]   None
# 13                                               None   None
# 14                                               None   None
# 15  [https://www.instagram.com/9kracing, https://i...   None
# 16    [https://www.instagram.com/genushair_official/]   None
# 17                                               None   None
# 18           [https://www.instagram.com/levi_le2386/]   None
# 19                                               None   None
# 20                                               None   None
# 21                                               None   None
# 22                                               None   None
# 23                                               None   None
# 24                                               None   None
# 25                                               None   None
# 26                                               None   None
# 27                                               None   None
# 28                                               None   None
# 29                                               None   None
# 30                                               None   None
# 31                                               None   None
#
#                                        RecordOwl_Link  \
# 0   https://recordowl.com/company/the-detailingco-...
# 1     https://recordowl.com/company/vegas-motor-works
# 2              https://recordowl.com/company/x-garage
# 3            https://recordowl.com/company/rms-motors
# 4            https://recordowl.com/company/pjs-garage
# 5      https://recordowl.com/company/super-j-services
# 6   https://recordowl.com/company/dailsun-autoservice
# 7       https://recordowl.com/company/apex-motorworks
# 8   https://recordowl.com/company/ignite-werkz-pte...
# 9   https://recordowl.com/company/yl-car-audio-acc...
# 10   https://recordowl.com/company/sin-seng-hong-auto
# 11  https://recordowl.com/company/eco-diesel-auto-...
# 12              https://recordowl.com/company/cartesy
# 13  https://recordowl.com/company/jssm-autosolutio...
# 14  https://recordowl.com/company/g7-workshop-priv...
# 15       https://recordowl.com/company/9k-motorsports
# 16          https://recordowl.com/company/genus-color
# 17  https://recordowl.com/company/lk-auto-accessories
# 18  https://recordowl.com/company/levi-automotive-...
# 19  https://recordowl.com/company/krt-private-limited
# 20     https://recordowl.com/company/ctk-auto-service
# 21     https://recordowl.com/company/j-a-auto-service
# 22         https://recordowl.com/company/rtac-pte-ltd
# 23     https://recordowl.com/company/fiftyone-pte-ltd
# 24  https://recordowl.com/company/li-sheng-worksho...
# 25  https://recordowl.com/company/lustrous-detaili...
# 26      https://recordowl.com/company/fresh-auto-care
# 27  https://recordowl.com/company/jin-wang-automob...
# 28  https://recordowl.com/company/buddy-spray-pte-ltd
# 29  https://recordowl.com/company/trans-tech-speci...
# 30        https://recordowl.com/company/masev-pte-ltd
# 31  https://recordowl.com/company/detailogy-privat...
#
#                                    operational_street operational_unit  \
# 0          61 WOODLANDS INDUSTRIAL PARK E9 E9 PREMIUM            01-20
# 1   9002 TAMPINES STREET 93 TAMPINES INDUSTRIAL PA...            01-40
# 2             15 KAKI BUKIT ROAD 4 BARTLEY BIZ CENTRE            01-53
# 3                     60 JALAN LAM HUAT CARROS CENTRE            03-27
# 4                       412 BUKIT BATOK WEST AVENUE 4           10-320
# 5                60 PAYA LEBAR ROAD PAYA LEBAR SQUARE            06-33
# 6             570A WOODLANDS AVENUE 1 CHAMPIONS COURT           07-888
# 7                             514 PASIR RIS STREET 52            06-91
# 8          1 KAKI BUKIT AVENUE 6 AUTOBAY @ KAKI BUKIT            02-61
# 9                160 SIN MING DRIVE SIN MING AUTOCITY            04-02
# 10                     80 EDGEDALE PLAINS THE TERRACE            01-03
# 11                  48 WHAMPOA EAST EIGHT RIVERSUITES             None
# 12                             706 PASIR RIS DRIVE 10           08-155
# 13         8 KAKI BUKIT AVENUE 4 PREMIER @ KAKI BUKIT            02-13
# 14                            1 CORPORATION DRIVE /19            06-18
# 15                                 401E FERNVALE LANE           08-328
# 16                  39 WOODLANDS CLOSE MEGA@WOODLANDS            03-04
# 17                 164 BISHAN STREET 13 BISHAN CRESTA           06-264
# 18                288 BISHAN STREET 24 BISHAN HEIGHTS            14-07
# 19                    60 JALAN LAM HUAT CARROS CENTRE            03-73
# 20           2 KAKI BUKIT AVENUE 2 KAKI BUKIT AUTOHUB            02-14
# 21                           6D MANDAI ESTATE M-SPACE           01-16M
# 22                     387 YISHUN RING ROAD SKY GREEN          02-1665
# 23                    60 JALAN LAM HUAT CARROS CENTRE            05-27
# 24  74 SUNGEI KADUT STREET 1 SUNGEI KADUT INDUSTRI...             None
# 25                    5 SOON LEE STREET PIONEER POINT            02-52
# 26                      68 KAKI BUKIT AVENUE 6 ARK@KB            03-03
# 27                                 67A TUAS BAY DRIVE            01-00
# 28                  25 KAKI BUKIT ROAD 4 SYNERGY @ KB            08-47
# 29                      18 SIN MING LANE MIDVIEW CITY            08-06
# 30          3791 JALAN BUKIT MERAH E-CENTRE @ REDHILL            08-12
# 31                 1 BUKIT BATOK CRESCENT WCEGA PLAZA            02-45
#
#    operational_postal_code                                operational_address  \
# 0                   757047  61 WOODLANDS INDUSTRIAL PARK E9 E9 PREMIUM 01-...
# 1                   528836  9002 TAMPINES STREET 93 TAMPINES INDUSTRIAL PA...
# 2                   417808  15 KAKI BUKIT ROAD 4 BARTLEY BIZ CENTRE 01-53 ...
# 3                   737869  60 JALAN LAM HUAT CARROS CENTRE 03-27 Singapor...
# 4                   650412  412 BUKIT BATOK WEST AVENUE 4 10-320 Singapore...
# 5                   409051  60 PAYA LEBAR ROAD PAYA LEBAR SQUARE 06-33 Sin...
# 6                   731570  570A WOODLANDS AVENUE 1 CHAMPIONS COURT 07-888...
# 7                   510514     514 PASIR RIS STREET 52 06-91 Singapore 510514
# 8                   417883  1 KAKI BUKIT AVENUE 6 AUTOBAY @ KAKI BUKIT 02-...
# 9                   575722  160 SIN MING DRIVE SIN MING AUTOCITY 04-02 Sin...
# 10                  828735  80 EDGEDALE PLAINS THE TERRACE 01-03 Singapore...
# 11                  338540  48 WHAMPOA EAST EIGHT RIVERSUITES Singapore 33...
# 12                  510706     706 PASIR RIS DRIVE 10 08-155 Singapore 510706
# 13                  415875  8 KAKI BUKIT AVENUE 4 PREMIER @ KAKI BUKIT 02-...
# 14                  619775     1 CORPORATION DRIVE /19 06-18 Singapore 619775
# 15                  795401         401E FERNVALE LANE 08-328 Singapore 795401
# 16                  737856  39 WOODLANDS CLOSE MEGA@WOODLANDS 03-04 Singap...
# 17                  570164  164 BISHAN STREET 13 BISHAN CRESTA 06-264 Sing...
# 18                  570288  288 BISHAN STREET 24 BISHAN HEIGHTS 14-07 Sing...
# 19                  737869  60 JALAN LAM HUAT CARROS CENTRE 03-73 Singapor...
# 20                  417921  2 KAKI BUKIT AVENUE 2 KAKI BUKIT AUTOHUB 02-14...
# 21                  729938   6D MANDAI ESTATE M-SPACE 01-16M Singapore 729938
# 22                  760387  387 YISHUN RING ROAD SKY GREEN 02-1665 Singapo...
# 23                  737869  60 JALAN LAM HUAT CARROS CENTRE 05-27 Singapor...
# 24                  729374  74 SUNGEI KADUT STREET 1 SUNGEI KADUT INDUSTRI...
# 25                  627607  5 SOON LEE STREET PIONEER POINT 02-52 Singapor...
# 26                  417896  68 KAKI BUKIT AVENUE 6 ARK@KB 03-03 Singapore ...
# 27                  636820          67A TUAS BAY DRIVE 01-00 Singapore 636820
# 28                  417800  25 KAKI BUKIT ROAD 4 SYNERGY @ KB 08-47 Singap...
# 29                  573960  18 SIN MING LANE MIDVIEW CITY 08-06 Singapore ...
# 30                  159471  3791 JALAN BUKIT MERAH E-CENTRE @ REDHILL 08-1...
# 31                  658064  1 BUKIT BATOK CRESCENT WCEGA PLAZA 02-45 Singa...
#
#    Phones_str
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 22       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
# 30       None
# 31       None

# %%
final_df_1.shape
# Out:
# (15, 16)

# %%
# RecordOwl_Leads.to_csv("./Fresh_Leads_19_11_25.csv")
