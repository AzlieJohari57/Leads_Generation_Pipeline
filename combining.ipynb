# %%
import os
import requests
import aiohttp
import asyncio
import nest_asyncio
import pandas as pd
import time
import scrapy
from scrapy_playwright.page import PageMethod
from bs4 import BeautifulSoup
import nest_asyncio
import glob
import numpy as np
import matplotlib.pyplot as plt
from fuzzywuzzy import fuzz, process
import re

# %%
parquet_path = "./Data_Lake/Tuition_n_ChildCare_592.parquet"
if os.path.exists(parquet_path):
    RecordOwl_Leads = pd.read_parquet(parquet_path, engine="fastparquet")
    print(f"Loaded {len(RecordOwl_Leads)} rows from {parquet_path}")
    print(RecordOwl_Leads.shape)
else:
    raise FileNotFoundError(f"Parquet file not found at {parquet_path}")


RecordOwl_Leads
# Out:
# Loaded 592 rows from ./Data_Lake/Tuition_n_ChildCare_592.parquet
# (592, 15)
#             UEN   Status Error                                   Emails  \
# 0    201727805K  success  None                                     None
# 1     53363337X  success  None                       [enquiry@edlab.sg]
# 2    202040317N  success  None              [enquiry@camelotinfant.com]
# 3    201334160E  success  None                  [ksatyamohan@yahoo.com]
# 4    202143113N  success  None                    [sgnoahark@gmail.com]
# ..          ...      ...   ...                                      ...
# 587  202429276K  success  None                                     None
# 588  200616128D  success  None                                     None
# 589  201429333R  success  None  [info@belvedereinternationalschool.com]
# 590  202002964M  success  None                                     None
# 591   53468959X  success  None                                     None
#
#           Phones                                            Website  \
# 0    +6567521170  https://www.mycareersfuture.gov.sg/job/educati...
# 1    +6581981320                                  https://edlab.sg/
# 2    +6598118333                     https://www.camelotinfant.com/
# 3    +6565691200                    https://globalachieversedu.com/
# 4    +6590588912                             https://en.sgpedu.com/
# ..           ...                                                ...
# 587         None                                               None
# 588         None                              https://arexevan.com/
# 589         None          https://belvedereinternationalschool.com/
# 590         None                                               None
# 591         None                                               None
#
#                                               Facebook  \
# 0                                                 None
# 1                                                 None
# 2      [https://www.facebook.com/camelot.river.valley]
# 3                   [https://www.facebook.com/gaecsg/]
# 4               [https://www.facebook.com/sgnoahsark/]
# ..                                                 ...
# 587                                               None
# 588  [https://www.facebook.com/p/Arexevan-Racing-10...
# 589           [https://www.facebook.com/belvedereint/]
# 590                                               None
# 591                                               None
#
#                                               LinkedIn  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4    [https://recordowl.com/company/linkedin.com/co...
# ..                                                 ...
# 587                                               None
# 588  [https://sg.linkedin.com/company/arexevan-racing]
# 589                                               None
# 590                                               None
# 591                                               None
#
#                                           Instagram TikTok  \
# 0                                              None   None
# 1              [https://www.instagram.com/edlab.sg]   None
# 2    [https://www.instagram.com/camelotrivervalley]   None
# 3                                              None   None
# 4                                              None   None
# ..                                              ...    ...
# 587                                            None   None
# 588                                            None   None
# 589       [https://www.instagram.com/belvedereint/]   None
# 590                                            None   None
# 591                                            None   None
#
#                                         RecordOwl_Link  \
# 0    https://recordowl.com/company/k-joy-educare-pt...
# 1         https://recordowl.com/company/tungstan-edlab
# 2    https://recordowl.com/company/preschool-infant...
# 3    https://recordowl.com/company/global-achievers...
# 4    https://recordowl.com/company/sg-noah-s-ark-ed...
# ..                                                 ...
# 587  https://recordowl.com/company/plantlove-studio...
# 588  https://recordowl.com/company/arexevan-racing-...
# 589  https://recordowl.com/company/belvedere-britis...
# 590  https://recordowl.com/company/iratos-singapore...
# 591     https://recordowl.com/company/elie-consultancy
#
#                                     operational_street operational_unit  \
# 0     87 MARINE PARADE CENTRAL MARINE PARADE PROMENADE           03-213
# 1                         23 FERNVALE LANE THE TOPIARY            02-29
# 2                                  45A CARMICHAEL ROAD             None
# 3                            242 JURONG EAST STREET 24           01-625
# 4                  140 PAYA LEBAR ROAD AZ @ PAYA LEBAR            05-25
# ..                                                 ...              ...
# 587                    184 STIRLING ROAD STIRLING RISE           21-246
# 588                  80 CHANGI ROAD CENTROPOD @ CHANGI            02-74
# 589                             27, PUNGGOL FIELD WALK             None
# 590                        4 SHENTON WAY SGX CENTRE II            15-01
# 591  93B TELOK BLANGAH STREET 31 TELOK BLANGAH PARC...             None
#
#     operational_postal_code                                operational_address
# 0                    440087  87 MARINE PARADE CENTRAL MARINE PARADE PROMENA...
# 1                    797501  23 FERNVALE LANE THE TOPIARY 02-29 Singapore 7...
# 2                    359826               45A CARMICHAEL ROAD Singapore 359826
# 3                    600242  242 JURONG EAST STREET 24 01-625 Singapore 600242
# 4                    409015  140 PAYA LEBAR ROAD AZ @ PAYA LEBAR 05-25 Sing...
# ..                      ...                                                ...
# 587                  140184  184 STIRLING ROAD STIRLING RISE 21-246 Singapo...
# 588                  419715  80 CHANGI ROAD CENTROPOD @ CHANGI 02-74 Singap...
# 589                  828649            27, PUNGGOL FIELD WALK Singapore 828649
# 590                  068807  4 SHENTON WAY SGX CENTRE II 15-01 Singapore 06...
# 591                  102093  93B TELOK BLANGAH STREET 31 TELOK BLANGAH PARC...
#
# [592 rows x 15 columns]

# %%
parquet_path = "./Data_Lake/WholeSale_358.parquet"
if os.path.exists(parquet_path):
    RecordOwl_Leads = pd.read_parquet(parquet_path, engine="fastparquet")
    print(f"Loaded {len(RecordOwl_Leads)} rows from {parquet_path}")
    print(RecordOwl_Leads.shape)
else:
    raise FileNotFoundError(f"Parquet file not found at {parquet_path}")


RecordOwl_Leads
# Out:
# Loaded 358 rows from ./Data_Lake/WholeSale_358.parquet
# (358, 10)
#             UEN                  Emails           Phones  \
# 0    201819442H  ['enquiry@bell-1.com']  ['+6562590183']
# 1    202534677Z                    None             None
# 2    201925464M                    None             None
# 3    202108485W                    None             None
# 4    202519922K                    None             None
# ..          ...                     ...              ...
# 353  202317887G                    None             None
# 354  201204768C                    None             None
# 355  200909666G                    None  ['+6562506506']
# 356  200805197N                    None             None
# 357   52874724W                    None             None
#
#                       Website                                      Facebook  \
# 0          https://bell-1.com  ['https://www.facebook.com/bell1lubricant/']
# 1                        None                                          None
# 2                        None                                          None
# 3                        None                                          None
# 4                        None                                          None
# ..                        ...                                           ...
# 353                      None                                          None
# 354                      None                                          None
# 355                      None                                          None
# 356  https://www.lamsoon.com/                                          None
# 357                      None                                          None
#
#     LinkedIn                                      Instagram  TikTok  \
# 0       None  ['https://www.instagram.com/bell1lubricant/']     NaN
# 1       None                                           None     NaN
# 2       None                                           None     NaN
# 3       None                                           None     NaN
# 4       None                                           None     NaN
# ..       ...                                            ...     ...
# 353     None                                           None     NaN
# 354     None                                           None     NaN
# 355     None                                           None     NaN
# 356     None                                           None     NaN
# 357     None                                           None     NaN
#
#                                         RecordOwl_Link  \
# 0    https://recordowl.com/company/bell-1-singapore...
# 1        https://recordowl.com/company/nuu-nii-pte-ltd
# 2    https://recordowl.com/company/cloud-frontier-a...
# 3    https://recordowl.com/company/golden-garland-c...
# 4    https://recordowl.com/company/xinyuan-shoes-pt...
# ..                                                 ...
# 353    https://recordowl.com/company/nutriland-pte-ltd
# 354                                               None
# 355  https://recordowl.com/company/unimetal-resourc...
# 356  https://recordowl.com/company/lamson-singapore...
# 357                                               None
#
#                               Error
# 0                              None
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# ..                              ...
# 353                            None
# 354  Company not found on RecordOwl
# 355                            None
# 356                            None
# 357  Company not found on RecordOwl
#
# [358 rows x 10 columns]

# %%
parquet_path = "./Data_Lake/CarMotor_Service_1050.parquet"
if os.path.exists(parquet_path):
    RecordOwl_Leads = pd.read_parquet(parquet_path, engine="fastparquet")
    print(f"Loaded {len(RecordOwl_Leads)} rows from {parquet_path}")
    print(RecordOwl_Leads.shape)
else:
    raise FileNotFoundError(f"Parquet file not found at {parquet_path}")


RecordOwl_Leads
# Out:
# Loaded 1050 rows from ./Data_Lake/CarMotor_Service_1050.parquet
# (1050, 16)
#              UEN   Status Error                                 Emails  \
# 0     202337162C  success  None                           hello@idwrap
# 1     202326625C  success  None                 jaya_automec@yahoo.com
# 2     202440698E  success  None                                   None
# 3     202105832K  success  None           hydrowashdetailing@gmail.com
# 4     202431492H  success  None                                   None
# ...          ...      ...   ...                                    ...
# 1045   53468383E  success  None                                   None
# 1046  202343910E  success  None  sales@rtac-consulting-engineering.com
# 1047   53468738E  success  None               Info@freshautocare.co.uk
# 1048  202514392K  success  None                 info@masev-designs.com
# 1049  202500469Z  success  None                                   None
#
#                Phones                                   Website  \
# 0     ['+6580611314']                        https://idwrap.sg/
# 1     ['+6591992566']                                      None
# 2     ['+6588434473']                                      None
# 3     ['+6580280868']                                      None
# 4     ['+6567416741']             https://1stautogarage.com.sg/
# ...               ...                                       ...
# 1045             None                 https://genushair.com/en/
# 1046             None  https://rtac-consulting-engineering.com/
# 1047             None              https://freshautocare.co.uk/
# 1048             None  https://masev-designs.com/contactus.html
# 1049             None                  https://detailogy.co.uk/
#
#                                                Facebook LinkedIn  \
# 0     https://www.facebook.com/idautowrap/, https://...     None
# 1                 https://www.facebook.com/jayaautomec/     None
# 2                                                  None     None
# 3           https://www.facebook.com/Hydrowashdetailing     None
# 4             https://www.facebook.com/1stAutoPteLtdSG/     None
# ...                                                 ...      ...
# 1045           https://www.facebook.com/genushairitalia     None
# 1046           https://www.facebook.com/rtacconsulting/     None
# 1047          https://www.facebook.com/freshautocareuk/     None
# 1048                  https://www.facebook.com/masev3d/     None
# 1049                https://www.facebook.com/detailogy/     None
#
#                                            Instagram TikTok  \
# 0                                               None   None
# 1             https://www.instagram.com/jayaautomec/   None
# 2     https://www.instagram.com/planetperformancesg/   None
# 3      https://www.instagram.com/hydrowashdetailing/   None
# 4                                               None   None
# ...                                              ...    ...
# 1045   https://www.instagram.com/genushair_official/   None
# 1046                                            None   None
# 1047                                            None   None
# 1048                                            None   None
# 1049                                            None   None
#
#                                          RecordOwl_Link  \
# 0     https://recordowl.com/company/id-auto-wrap-pte...
# 1     https://recordowl.com/company/jaya-automec-sg-...
# 2     https://recordowl.com/company/planet-performan...
# 3     https://recordowl.com/company/hydrowash-detail...
# 4     https://recordowl.com/company/first-automobile...
# ...                                                 ...
# 1045          https://recordowl.com/company/genus-color
# 1046         https://recordowl.com/company/rtac-pte-ltd
# 1047      https://recordowl.com/company/fresh-auto-care
# 1048        https://recordowl.com/company/masev-pte-ltd
# 1049  https://recordowl.com/company/detailogy-privat...
#
#                                  operational_street operational_unit  \
# 0                   237 ALEXANDRA ROAD THE ALEXCIER            02-05
# 1     414 ANG MO KIO AVENUE 10 TECK GHEE HEARTLANDS           03-929
# 2                   60 JALAN LAM HUAT CARROS CENTRE            03-11
# 3        105 BUKIT BATOK CENTRAL NORTH POINT BIZHUB           02-257
# 4                   60 JALAN LAM HUAT CARROS CENTRE            03-42
# ...                                             ...              ...
# 1045              39 WOODLANDS CLOSE MEGA@WOODLANDS            03-04
# 1046                 387 YISHUN RING ROAD SKY GREEN          02-1665
# 1047                  68 KAKI BUKIT AVENUE 6 ARK@KB            03-03
# 1048      3791 JALAN BUKIT MERAH E-CENTRE @ REDHILL            08-12
# 1049             1 BUKIT BATOK CRESCENT WCEGA PLAZA            02-45
#
#      operational_postal_code  \
# 0                     159929
# 1                     560414
# 2                     737869
# 3                     650105
# 4                     737869
# ...                      ...
# 1045                  737856
# 1046                  760387
# 1047                  417896
# 1048                  159471
# 1049                  658064
#
#                                     operational_address Phones_str
# 0     237 ALEXANDRA ROAD THE ALEXCIER 02-05 Singapor...       None
# 1     414 ANG MO KIO AVENUE 10 TECK GHEE HEARTLANDS ...       None
# 2     60 JALAN LAM HUAT CARROS CENTRE 03-11 Singapor...       None
# 3     105 BUKIT BATOK CENTRAL NORTH POINT BIZHUB 02-...       None
# 4     60 JALAN LAM HUAT CARROS CENTRE 03-42 Singapor...       None
# ...                                                 ...        ...
# 1045  39 WOODLANDS CLOSE MEGA@WOODLANDS 03-04 Singap...       None
# 1046  387 YISHUN RING ROAD SKY GREEN 02-1665 Singapo...       None
# 1047  68 KAKI BUKIT AVENUE 6 ARK@KB 03-03 Singapore ...       None
# 1048  3791 JALAN BUKIT MERAH E-CENTRE @ REDHILL 08-1...       None
# 1049  1 BUKIT BATOK CRESCENT WCEGA PLAZA 02-45 Singa...       None
#
# [1050 rows x 16 columns]
