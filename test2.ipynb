# %%
from apify_client import ApifyClient
import pandas as pd

# Initialize the ApifyClient with your API token
client = ApifyClient("apify_api_0HQ8fc5fw5T1aosdacxKQNQYVBAEwi3tXaJc")

# Prepare the Actor input
run_input = {
    "urls": ["https://www.linkedin.com/company/techhousesg/?originalSubdomain=sg"],
    "sort_order": "relevance",
    "max_employees": 100,
    "proxyConfiguration": {
        "useApifyProxy": True,
        "apifyProxyGroups": ["RESIDENTIAL"],
        "apifyProxyCountry": "US",
    },
}

# Run the Actor and wait for it to finish
run = client.actor("2IMkeDI6D9ZzyLMdX").call(run_input=run_input)

# Fetch Actor results from the run's dataset and save to DataFrame
results = []
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    results.append(item)

# Create DataFrame from results
df = pd.DataFrame(results)
print(f"Scraped {len(df)} records")
df
# Out:
# [apify.linkedin-company-employees-scraper runId:HWGE1r0Y91OPBFy59] -> Status: RUNNING, Message:
# [apify.linkedin-company-employees-scraper runId:HWGE1r0Y91OPBFy59] -> 2025-11-05T02:02:58.457Z ACTOR: Pulling container image of build xh2OdPLsSNkPhz1WW from registry.
# [apify.linkedin-company-employees-scraper runId:HWGE1r0Y91OPBFy59] -> 2025-11-05T02:03:02.075Z ACTOR: Creating container.
# [apify.linkedin-company-employees-scraper runId:HWGE1r0Y91OPBFy59] -> 2025-11-05T02:03:02.273Z ACTOR: Starting container.
# [apify.linkedin-company-employees-scraper runId:HWGE1r0Y91OPBFy59] -> 2025-11-05T02:03:03.990Z Actor is running on the Apify platform, `disable_browser_sandbox` was changed to True.
# [apify.linkedin-company-employees-scraper runId:HWGE1r0Y91OPBFy59] -> 2025-11-05T02:03:03.996Z [apify] INFO  Initializing Actor ({"apify_sdk_version": "3.0.2", "apify_client_version": "2.2.0", "crawlee_version": "1.0.3", "python_version": "3.13.9", "os": "linux"})
# ...

# %%
from apify_client import ApifyClient

# Initialize the ApifyClient with your API token
client = ApifyClient("apify_api_yNR85etaHpLtBzPoVozVVXUsCZe54u2Ffog1")

# Prepare the Actor input
run_input = {
    "max_result": 10,
    "contact_job_titles": None,
    "contact_levels": None,
    "email_status": ["verified"],
    "company_num_employees_range": None,
    "contact_location": None,
    "company_domains": None,
    "company_industry": None,
    "contact_min_total_year_of_experience": None,
    "contact_max_total_year_of_experience": None,
    "min_revenue": None,
    "max_revenue": None,
}

# Run the Actor and wait for it to finish
run = client.actor("heLL6fUofdPgRXZie").call(run_input=run_input)

# Fetch and print Actor results from the run's dataset (if there are any)
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    print(item)
# Out:
# [apify.leads-generator runId:HDWhngjiQphr0EVFy] -> Status: RUNNING, Message:
# [apify.leads-generator runId:HDWhngjiQphr0EVFy] -> 2025-11-05T03:16:31.692Z ACTOR: Pulling container image of build xArAjbdMnPd5Cpi3q from registry.
# [apify.leads-generator runId:HDWhngjiQphr0EVFy] -> 2025-11-05T03:16:31.700Z ACTOR: Creating container.
# [apify.leads-generator runId:HDWhngjiQphr0EVFy] -> 2025-11-05T03:16:31.763Z ACTOR: Starting container.
# [apify.leads-generator runId:HDWhngjiQphr0EVFy] -> 2025-11-05T03:16:34.366Z Actor initialized
# [apify.leads-generator runId:HDWhngjiQphr0EVFy] -> 2025-11-05T03:16:34.371Z INFO  System info {"apifyVersion":"3.5.1","apifyClientVersion":"2.19.0","crawleeVersion":"3.15.2","osType":"Linux","nodeVersion":"v22.20.0"}
# [apify.leads-generator runId:HDWhngjiQphr0EVFy] -> Status: SUCCEEDED, Message:
# Scraped 0 records from Singapore
# Empty DataFrame
# Columns: []
# Index: []

# %%
from apify_client import ApifyClient
import pandas as pd

# Initialize the ApifyClient with your API token
client = ApifyClient("apify_api_yNR85etaHpLtBzPoVozVVXUsCZe54u2Ffog1")

# Prepare the Actor input
run_input = {
    "max_result": 10,
    "email_status": ["unverified"],
    "contact_location": ["Singapore"],  # Filter for Singapore contacts
}

# Run the Actor and wait for it to finish
run = client.actor("heLL6fUofdPgRXZie").call(run_input=run_input)

# Fetch Actor results from the run's dataset and save to DataFrame
results = []
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    results.append(item)

# Create DataFrame from results
df = pd.DataFrame(results)
print(f"Scraped {len(df)} records from Singapore (unverified emails)")
df
# Out:
# [apify.leads-generator runId:377I2ZscnQHaCuKes] -> Status: RUNNING, Message:
# [apify.leads-generator runId:377I2ZscnQHaCuKes] -> 2025-11-05T03:19:01.837Z ACTOR: Pulling container image of build xArAjbdMnPd5Cpi3q from registry.
# [apify.leads-generator runId:377I2ZscnQHaCuKes] -> 2025-11-05T03:19:01.839Z ACTOR: Creating container.
# [apify.leads-generator runId:377I2ZscnQHaCuKes] -> 2025-11-05T03:19:01.882Z ACTOR: Starting container.
# [apify.leads-generator runId:377I2ZscnQHaCuKes] -> 2025-11-05T03:19:04.500Z Actor initialized
# [apify.leads-generator runId:377I2ZscnQHaCuKes] -> 2025-11-05T03:19:04.506Z INFO  System info {"apifyVersion":"3.5.1","apifyClientVersion":"2.19.0","crawleeVersion":"3.15.2","osType":"Linux","nodeVersion":"v22.20.0"}
# [apify.leads-generator runId:377I2ZscnQHaCuKes] -> Status: SUCCEEDED, Message:
# Scraped 0 records from Singapore (unverified emails)
# Empty DataFrame
# Columns: []
# Index: []
