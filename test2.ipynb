# %%
import os
import requests
import aiohttp
import asyncio
import nest_asyncio
import pandas as pd
import time
import scrapy
from scrapy_playwright.page import PageMethod
from bs4 import BeautifulSoup
import nest_asyncio
import glob
import numpy as np
import matplotlib.pyplot as plt
from fuzzywuzzy import fuzz, process
import re
from apify_client import ApifyClient

# %%
parquet_path = "./Staging/Silver/carmotor_proceesd.parquet"
if os.path.exists(parquet_path):
    carmotor_website = pd.read_parquet(parquet_path, engine="fastparquet")
    print(f"Loaded {len(carmotor_website)} rows from {parquet_path}")
    print(carmotor_website.shape)
else:
    raise FileNotFoundError(f"Parquet file not found at {parquet_path}")


carmotor_website.
# Out:
# Loaded 50 rows from ./Staging/Silver/carmotor_proceesd.parquet
# (50, 16)
#            UEN   Status Error                         Emails       Phones  \
# 40  202026794D  success  None    [info@premiumdetailing.biz]  +6588501200
# 41   53432157K  success  None                           None  +6588501200
# 42  202301066W  success  None      [capsautowerkz@gmail.com]  +6592960203
# 43  202026096D  success  None      [capsautowerkz@gmail.com]  +6592960203
# 44  202300864R  success  None                           None         None
# 45   53471316E  success  None         [admin@xgarage.com.my]         None
# 46   53434305L  success  None  [ecodieseldynamics@gmail.com]         None
# 47  202227809C  success  None                           None         None
# 48   53482117X  success  None      [jason@9kmotorsports.com]         None
# 49   53468383E  success  None                           None         None
#
#                                         Website  \
# ...

# %%
parquet_path = "./Staging/Silver/carmotor_proceesd.parquet"
if os.path.exists(parquet_path):
    carmotor_website = pd.read_parquet(parquet_path, engine="fastparquet")
    print(f"Loaded {len(carmotor_website)} rows from {parquet_path}")
    print(carmotor_website.shape)
else:
    raise FileNotFoundError(f"Parquet file not found at {parquet_path}")


carmotor_website.tail(10)
